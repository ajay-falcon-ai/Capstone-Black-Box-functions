# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %run ../pca/pca.ipynb
pca("Function_5")
# Out:
# Component 1
# Fraction of total variance explained by this component:0.3848
# Total fraction of variance explained by the first 1 component(s): 0.3848
#
# Component 2
# Fraction of total variance explained by this component:0.2536
# Total fraction of variance explained by the first 2 component(s): 0.6384
#
# Component 3
# Fraction of total variance explained by this component:0.2068
# Total fraction of variance explained by the first 3 component(s): 0.8452
#
# Component 4
# Fraction of total variance explained by this component:0.1548
# Total fraction of variance explained by the first 4 component(s): 1.0000
