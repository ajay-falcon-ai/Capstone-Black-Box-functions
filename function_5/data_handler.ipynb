# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
# %run ../plot_functions.ipynb

# %%
# Track sources
source_labels = ['file'] * len(inputs)

# %%
#Append week-1 data.
#Function 5:	[0.183674, 0.857143, 0.816327, 0.877551]
inputs = np.append(inputs, [[0.183674, 0.857143, 0.816327, 0.877551]], axis=0)
#Function 5:	872.3074873002278
outputs = np.append(outputs, [872.3074873002278], axis=0)

# %%
source_labels.append('week-1')

# %%
#Append week-2 data.
#Function 5:	[0.272727, 0.848484, 0.848485, 0.818182]
inputs = np.append(inputs, [[0.272727, 0.848484, 0.848485, 0.818182]], axis=0)
#Function 5:	743.1182481623213
outputs = np.append(outputs, [743.1182481623213], axis=0)

# %%
source_labels.append('week-2')

# %%
#Append week-3 data.
#Function 5:	[0.254786, 0.802969, 0.855045, 0.937720]
inputs = np.append(inputs, [[0.272727, 0.848484, 0.848485, 0.818182]], axis=0)
#Function 5:	1118.8725469008125
outputs = np.append(outputs, [1118.8725469008125], axis=0)
source_labels.append('week-3')

# %%
#Append week-4 data.
#Function 5:	[0.242085, 0.848724, 0.469207, 0.893286]
inputs = np.append(inputs, [[0.242085, 0.848724, 0.469207, 0.893286]], axis=0)
#Function 5:	386.6818739904094
outputs = np.append(outputs, [386.6818739904094], axis=0)
source_labels.append('week-4')

# %%
# Create DataFrame
df = pd.DataFrame(inputs, columns=['var-1', 'var-2', 'var-3', 'var-4'])
df['yield'] = outputs
df['source'] = source_labels

# Sort by transformed-side effect (larger is better)
df_sorted = df.sort_values(by='yield', ascending=False)

# Preview
print(df_sorted)
# Out:
#        var-1     var-2     var-3     var-4        yield  source
# 22  0.272727  0.848484  0.848485  0.818182  1118.872547  week-3
# 15  0.224189  0.846480  0.879484  0.878516  1088.859618    file
# 20  0.183674  0.857143  0.816327  0.877551   872.307487  week-1
# 21  0.272727  0.848484  0.848485  0.818182   743.118248  week-2
# 18  0.119879  0.862540  0.643331  0.849804   431.612757    file
# 14  0.438933  0.774092  0.378167  0.933696   355.806818    file
# 4   0.836478  0.193610  0.663893  0.785649   258.370525    file
# 9   0.463442  0.630025  0.107906  0.957644   233.223610    file
# 7   0.352356  0.322242  0.116979  0.473113   109.571876    file
# 13  0.511142  0.817957  0.728710  0.112354    79.729130    file
# 5   0.683432  0.118663  0.829046  0.567577    78.434389    file
# 0   0.191447  0.038193  0.607418  0.414584    64.443440    file
# 11  0.583973  0.147243  0.348097  0.428615    64.420147    file
# 12  0.306889  0.316878  0.622634  0.095399    63.476716    file
# 6   0.553621  0.667350  0.323806  0.814870    57.571537    file
# 17  0.355482  0.639619  0.417618  0.122604    45.181570    file
# 16  0.725262  0.479870  0.088947  0.759760    28.866752    file
# 10  0.677491  0.358510  0.479592  0.072880    24.423088    file
# 1   0.758653  0.536518  0.656000  0.360342    18.301380    file
# 19  0.126885  0.153430  0.770162  0.190518     9.972332    file
# 8   0.153786  0.729382  0.422598  0.443074     8.847992    file
# 3   0.706051  0.534192  0.264243  0.482088     4.210898    file
# 2   0.438350  0.804340  0.210245  0.151295     0.112940    file

# %%
plot_output_points(df_sorted, scale_factor=500.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_40876/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
