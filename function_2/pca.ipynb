# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %run ../pca/pca.ipynb
pca("Function_2")
# Out:
# Component 1
# Fraction of total variance explained by this component:0.5373
# Total fraction of variance explained by the first 1 component(s): 0.5373
#
# Component 2
# Fraction of total variance explained by this component:0.4627
# Total fraction of variance explained by the first 2 component(s): 1.0000
