# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
#Process data
# %run data_handler.ipynb
# Out:
#     number-1  number-2  log-likelyhood-score  source
# 9   0.702637  0.926564              0.611205    file
# 0   0.665800  0.123969              0.538996    file
# 12  0.722766  0.839711              0.533827  week-3
# 1   0.877791  0.778628              0.420586    file
# 3   0.845275  0.711120              0.293993    file
# 6   0.438166  0.685018              0.244619    file
# 4   0.454647  0.290455              0.214965    file
# 11  0.616162  1.000000              0.180119  week-2
# 10  0.818182  0.939394              0.051646  week-1
# 7   0.341750  0.028698              0.038749    file
# 5   0.577713  0.771973              0.023106    file
# 8   0.338648  0.213867             -0.013858    file
# 2   0.142699  0.349005             -0.065624    file
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_44290/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
kernel = RBF(length_scale=1.0) + WhiteKernel(noise_level=1.0)
kernel = None
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='PI xi=0.01', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.01, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='PI xi=0.05', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.9, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='PI xi=0.9', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.9, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='UCB kappa=1.0', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='UCB kappa=2.0', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='UCB kappa=3.0', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.69187316 0.26335551]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.01, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='EI xi=0.01', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.01, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='EI xi=0.05', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, grid_size=400, apply_scaling=True, filter_mode='gp')
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='EI xi=0.1', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  2
# Input space dimension: 2
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 2114 candidates near decision boundary (|margin| < 0.2)
# Excluded 157886 candidates from consideration
# Final grid shape: (2114, 2)
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  2114
# Std   2114
# Next query point: [0.7879603  0.17528767]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.01, 'kappa': None, 'x': array([0.7879603 , 0.17528767]), 'score': 0.10539229292413999, 'dim': 2}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.7879603 , 0.17528767]), 'score': 0.09759233114140065, 'dim': 2}
# {'method': 'PI', 'xi': 0.9, 'kappa': None, 'x': array([0.7879603 , 0.17528767]), 'score': 0.01287327187750502, 'dim': 2}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.7879603 , 0.17528767]), 'score': 1.4788752303189692, 'dim': 2}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.7879603 , 0.17528767]), 'score': 2.388335313386982, 'dim': 2}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.69187316, 0.26335551]), 'score': 3.302841835257082, 'dim': 2}
# {'method': 'EI', 'xi': 0.01, 'kappa': None, 'x': array([0.7879603 , 0.17528767]), 'score': 0.04587133303160838, 'dim': 2}
# {'method': 'EI', 'xi': 0.05, 'kappa': None, 'x': array([0.7879603 , 0.17528767]), 'score': 0.041813096553734025, 'dim': 2}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.7879603 , 0.17528767]), 'score': 0.037164845092771626, 'dim': 2}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 2
# x: [0.691873, 0.263356]
# Score: 3.302842
# {'method': 'UCB',
#  'xi': None,
#  'kappa': 3.0,
#  'x': array([0.69187316, 0.26335551]),
#  'score': 3.302841835257082,
#  'dim': 2}

# %%
#add points to dataframe
add_points_to_df(df_sorted, query_results)
pd.set_option('display.max_rows', None)
print(df_sorted)
# Out:
#     number-1  number-2  log-likelyhood-score  source
# 9   0.702637  0.926564              0.611205    file
# 0   0.665800  0.123969              0.538996    file
# 12  0.722766  0.839711              0.533827  week-3
# 1   0.877791  0.778628              0.420586    file
# 3   0.845275  0.711120              0.293993    file
# 6   0.438166  0.685018              0.244619    file
# 4   0.454647  0.290455              0.214965    file
# 11  0.616162  1.000000              0.180119  week-2
# 10  0.818182  0.939394              0.051646  week-1
# 7   0.341750  0.028698              0.038749    file
# 5   0.577713  0.771973              0.023106    file
# 8   0.338648  0.213867             -0.013858    file
# 2   0.142699  0.349005             -0.065624    file
# 13  0.787960  0.175288                   NaN  week-x
# 14  0.787960  0.175288                   NaN  week-x
# 15  0.787960  0.175288                   NaN  week-x
# 16  0.787960  0.175288                   NaN  week-x
# 17  0.787960  0.175288                   NaN  week-x
# 18  0.691873  0.263356                   NaN  week-x
# 19  0.787960  0.175288                   NaN  week-x
# 20  0.787960  0.175288                   NaN  week-x
# 21  0.787960  0.175288                   NaN  week-x

# %%
plot_output_points(df_sorted, scale_factor=1.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_44290/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
