# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
#Process data
# %run data_handler.ipynb
# Out:
#     number-1  number-2  log-likelyhood-score  source
# 9   0.702637  0.926564              0.611205    file
# 0   0.665800  0.123969              0.538996    file
# 1   0.877791  0.778628              0.420586    file
# 3   0.845275  0.711120              0.293993    file
# 6   0.438166  0.685018              0.244619    file
# 4   0.454647  0.290455              0.214965    file
# 11  0.616162  1.000000              0.180119  week-2
# 10  0.818182  0.939394              0.051646  week-1
# 7   0.341750  0.028698              0.038749    file
# 5   0.577713  0.771973              0.023106    file
# 8   0.338648  0.213867             -0.013858    file
# 2   0.142699  0.349005             -0.065624    file

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
kernel = RBF(length_scale=1.0) + WhiteKernel(noise_level=1.0)
kernel = None
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='PI xi=0.01', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.01, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.6944298  0.91069862]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='PI xi=0.05', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.6944298  0.91069862]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.9, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='PI xi=0.9', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.9, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.71332055 0.85154194]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='UCB kappa=1.0', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.70387518 0.87520461]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='UCB kappa=2.0', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.71332055 0.85154194]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='UCB kappa=3.0', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.72276592 0.8397106 ]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.01, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='EI xi=0.01', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.01, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.6944298  0.88703595]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='EI xi=0.05', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.6944298  0.88703595]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, apply_scaling=True, kernel=kernel)
print("Next query point:", next_point)
#plot_acquisition_heatmap(X, acq_vals, grid, next_query=next_point, title='EI xi=0.1', cmap='viridis')
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  2
# Dimension of input space: 2
# Each axis has 100 points before downsampling
# Each axis has 100 points after downsampling
# Function will evaluate across: 10000 points
# Known data volume: 0.40845672366062813
# Grid volume: 1.095275291933419
# Coverage ratio of known data to grid volume: 0.37292608229991725
# Mean  10000
# Std   10000
# Next query point: [0.6944298  0.88703595]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.01, 'kappa': None, 'x': array([0.6944298 , 0.91069862]), 'score': 0.7913785889264389, 'dim': 2}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.6944298 , 0.91069862]), 'score': 0.7064357488739429, 'dim': 2}
# {'method': 'PI', 'xi': 0.9, 'kappa': None, 'x': array([0.71332055, 0.85154194]), 'score': 0.029666564341324055, 'dim': 2}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.70387518, 0.87520461]), 'score': 2.3624331501564013, 'dim': 2}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.71332055, 0.85154194]), 'score': 2.8529665957001207, 'dim': 2}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.72276592, 0.8397106 ]), 'score': 3.475775636557274, 'dim': 2}
# {'method': 'EI', 'xi': 0.01, 'kappa': None, 'x': array([0.6944298 , 0.88703595]), 'score': 0.2010758468264131, 'dim': 2}
# {'method': 'EI', 'xi': 0.05, 'kappa': None, 'x': array([0.6944298 , 0.88703595]), 'score': 0.17617726483710722, 'dim': 2}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.6944298 , 0.88703595]), 'score': 0.14770804566741622, 'dim': 2}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 2
# x: [0.722766, 0.839711]
# Score: 3.475776
# {'method': 'UCB',
#  'xi': None,
#  'kappa': 3.0,
#  'x': array([0.72276592, 0.8397106 ]),
#  'score': 3.475775636557274,
#  'dim': 2}

# %%
#add points to dataframe
add_points_to_df(df_sorted, query_results)
pd.set_option('display.max_rows', None)
print(df_sorted)
# Out:
#     number-1  number-2  log-likelyhood-score  source
# 9   0.702637  0.926564              0.611205    file
# 0   0.665800  0.123969              0.538996    file
# 1   0.877791  0.778628              0.420586    file
# 3   0.845275  0.711120              0.293993    file
# 6   0.438166  0.685018              0.244619    file
# 4   0.454647  0.290455              0.214965    file
# 11  0.616162  1.000000              0.180119  week-2
# 10  0.818182  0.939394              0.051646  week-1
# 7   0.341750  0.028698              0.038749    file
# 5   0.577713  0.771973              0.023106    file
# 8   0.338648  0.213867             -0.013858    file
# 2   0.142699  0.349005             -0.065624    file
# 12  0.694430  0.910699                   NaN  week-x
# 13  0.694430  0.910699                   NaN  week-x
# 14  0.713321  0.851542                   NaN  week-x
# 15  0.703875  0.875205                   NaN  week-x
# 16  0.713321  0.851542                   NaN  week-x
# 17  0.722766  0.839711                   NaN  week-x
# 18  0.694430  0.887036                   NaN  week-x
# 19  0.694430  0.887036                   NaN  week-x
# 20  0.694430  0.887036                   NaN  week-x

# %%
plot_output_points(df_sorted, scale_factor=1.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_24280/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
