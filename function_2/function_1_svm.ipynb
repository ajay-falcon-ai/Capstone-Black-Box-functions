# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import svm
import math
import warnings
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
#Process data
# %run data_handler.ipynb
# Out:
#     number-1  number-2  log-likelyhood-score  source
# 9   0.702637  0.926564              0.611205    file
# 0   0.665800  0.123969              0.538996    file
# 12  0.722766  0.839711              0.533827  week-3
# 1   0.877791  0.778628              0.420586    file
# 3   0.845275  0.711120              0.293993    file
# 6   0.438166  0.685018              0.244619    file
# 4   0.454647  0.290455              0.214965    file
# 11  0.616162  1.000000              0.180119  week-2
# 10  0.818182  0.939394              0.051646  week-1
# 7   0.341750  0.028698              0.038749    file
# 5   0.577713  0.771973              0.023106    file
# 8   0.338648  0.213867             -0.013858    file
# 2   0.142699  0.349005             -0.065624    file
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_81386/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
#color = np.concatenate((np.repeat("red", n_red), np.repeat("blue", n_blue)))

#plt.scatter(X[:, 0], X[:, 1], c=color, alpha=0.5)
#plt.xlabel("$x_1$", size=15)
#plt.ylabel("$x_2$", size=15)
#plt.title("Two classes that are linearly separable")
#plt.show()

# %%
clf = svm.SVC(kernel = 'linear', C = 0.01)
clf.fit(X, y)
cm = confusion_matrix(y, clf.predict(X))
cmd = ConfusionMatrixDisplay(cm, display_labels=np.unique(y))
cmd.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 clf = svm.SVC(kernel = 'linear', C = 0.01)
# ----> 2 clf.fit(X, y)
#       3 cm = confusion_matrix(y, clf.predict(X))
#       4 cmd = ConfusionMatrixDisplay(cm, display_labels=np.unique(y))
#
# File /opt/anaconda3/envs/tf-macos/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/tf-macos/lib/python3.10/site-packages/sklearn/svm/_base.py:207, in BaseLibSVM.fit(self, X, y, sample_weight)
#     196 else:
#     197     X, y = validate_data(
#     198         self,
#     199         X,
#    (...)
#     204         accept_large_sparse=False,
#     205     )
# --> 207 y = self._validate_targets(y)
#     209 sample_weight = np.asarray(
#     210     [] if sample_weight is None else sample_weight, dtype=np.float64
#     211 )
#     212 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File /opt/anaconda3/envs/tf-macos/lib/python3.10/site-packages/sklearn/svm/_base.py:747, in BaseSVC._validate_targets(self, y)
#     745 def _validate_targets(self, y):
#     746     y_ = column_or_1d(y, warn=True)
# --> 747     check_classification_targets(y)
#     748     cls, y = np.unique(y_, return_inverse=True)
#     749     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# File /opt/anaconda3/envs/tf-macos/lib/python3.10/site-packages/sklearn/utils/multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)
#     219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
with warnings.catch_warnings(): #Otherwise, the package might throw an error that there is no "boundary" when all samples belong to the same class.
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf, legend=2, colors = "red,blue", markers= "o", zoom_factor = 10);
    ax=plt.gca();
    plt.title("Linear decision boundary")
    plt.show();

# %%
find_best_candidate(query_results)

# %%
#add points to dataframe
#print(df)
add_points_to_df(df_sorted, query_results)
pd.set_option('display.max_rows', None)
print(df_sorted)

# %%
plot_output_points(df_sorted, scale_factor=1.0, yield_scale_factor=100.0, nan_marker='o')
