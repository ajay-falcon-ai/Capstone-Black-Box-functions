# %%
import numpy as np

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
print(len(inputs))
print(inputs)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)
print(len(outputs))
print(outputs)
# Out:
# 10
# [[0.66579958 0.12396913]
#  [0.87779099 0.7786275 ]
#  [0.14269907 0.34900513]
#  [0.84527543 0.71112027]
#  [0.45464714 0.29045518]
#  [0.57771284 0.77197318]
#  [0.43816606 0.68501826]
#  [0.34174959 0.02869772]
#  [0.33864816 0.21386725]
#  [0.70263656 0.9265642 ]]
# 10
# [ 0.53899612  0.42058624 -0.06562362  0.29399291  0.21496451  0.02310555
#   0.24461934  0.03874902 -0.01385762  0.61120522]

# %%
def print_csv(arr):
    """
    Print a NumPy array as CSV:
    - One row per line
    - Comma-separated columns
    - If there's only one row, print each value on a new line
    """
    arr = np.asarray(arr)

    if arr.ndim == 0:
        # Scalar
        print(str(arr.item()))

    elif arr.ndim == 1:
        # 1D: treat as single row → print each value on its own line
        for val in arr:
            print(str(val))

    elif arr.ndim == 2:
        if arr.shape[0] == 1:
            # Single row → print each column value on its own line
            for val in arr[0]:
                print(str(val))
        else:
            # Multiple rows → print comma-separated
            for row in arr:
                print(','.join(map(str, row)))

    else:
        # 3D+ → flatten each leading slice to a row
        reshaped = arr.reshape(arr.shape[0], -1)
        for row in reshaped:
            print(','.join(map(str, row)))
print_csv(inputs)
print_csv(outputs)
# Out:
# 0.6657995800131589,0.12396912767534907
# 0.8777909889953304,0.7786275008473289
# 0.14269907423594608,0.34900513057320015
# 0.8452754286767249,0.7111202665952655
# 0.45464714105124415,0.2904551797740609
# 0.5777128444074784,0.7719731841154063
# 0.4381660616117107,0.6850182567997548
# 0.34174959302885033,0.028697719822277867
# 0.33864815688701766,0.21386724563864368
# 0.7026365569244406,0.9265641975455574
# 0.5389961189269181
# 0.42058623962798264
# -0.06562362443733738
# 0.293992912410866
# 0.2149645101004509
# 0.023105549798190586
# 0.24461934400448035
# 0.0387490151561584
# -0.013857618149729824
# 0.6112052157614438
