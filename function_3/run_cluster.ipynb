# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

from clustering.run_clustering import run_clustering
from clustering.cluster_analysis import ClusterReport
from clustering.handler_factory import get_handler

function_name = "function_3"

labels, model, df, df_scaled = run_clustering(function_name, method="kmeans", n_clusters=4)
handler = get_handler(function_name)
print(f"Clustering Report for function: {function_name}, method: kmean, n_clusters: 4")
report = ClusterReport(df, labels, handler.output_label, function_name)
report.generate()

labels, model, df, df_scaled = run_clustering(function_name, method="hierarchical", n_clusters=3)
handler = get_handler(function_name)
print(f"Clustering Report for function: {function_name}, method: hierarchical, n_clusters: 3")
report = ClusterReport(df, labels, handler.output_label, function_name)
report.generate()

labels, model, df, df_scaled = run_clustering(function_name, method="hierarchical", n_clusters=-1)
handler = get_handler(function_name)
print(f"Clustering Report for function: {function_name}, method: hierarchical, n_clusters: -1")
report = ClusterReport(df, labels, handler.output_label, function_name)
report.generate()
# Out:
# Data:
#      compound-1  compound-2  compound-3  trans-side-effect
# 0     0.171525    0.343917    0.248737          -0.112122
# 1     0.242114    0.644074    0.272433          -0.087963
# 2     0.534906    0.398501    0.173389          -0.111415
# 3     0.492581    0.611593    0.340176          -0.034835
# 4     0.134622    0.219917    0.458206          -0.048008
# 5     0.345523    0.941360    0.269363          -0.110621
# 6     0.151837    0.439991    0.990882          -0.398926
# 7     0.645503    0.397143    0.919771          -0.113869
# 8     0.746912    0.284196    0.226300          -0.131461
# 9     0.170477    0.697032    0.149169          -0.094190
# 10    0.220549    0.297825    0.343555          -0.046947
# 11    0.666014    0.671985    0.246295          -0.105965
# 12    0.046809    0.231360    0.770618          -0.118048
# 13    0.600097    0.725136    0.066089          -0.036378
# 14    0.965995    0.861120    0.566829          -0.056758
# 15    0.464647    0.666667    0.171718          -0.111186
# 16    0.303031    0.242424    0.474748          -0.030680
# 17    0.263346    0.138532    0.363743          -0.048179
# 18    0.448900    0.470829    0.414315          -0.020404
# 19    0.357938    0.038532    0.517008          -0.117539
# 20    0.116130    0.051462    0.314168          -0.148291
# 21    0.137356    0.196578    0.292441          -0.126356
# 22    0.394576    0.615328    0.367214          -0.037692
# 23    0.450000    0.470000    0.400000          -0.029032
# 24    0.476973    1.036177    1.085450          -0.751389
# Scaled data:
#      compound-1  compound-2  compound-3
# 0     0.135681    0.306106    0.179179
# 1     0.212477    0.606972    0.202425
# 2     0.531010    0.360819    0.105262
# 3     0.484964    0.574414    0.268882
# 4     0.095533    0.181813    0.384670
# 5     0.324977    0.904959    0.199414
# 6     0.114262    0.402406    0.907228
# 7     0.651331    0.359457    0.837468
# 8     0.761655    0.246244    0.157168
# 9     0.134541    0.660055    0.081503
# 10    0.189016    0.259905    0.272197
# 11    0.673645    0.634948    0.176784
# 12    0.000000    0.193283    0.691147
# 13    0.601933    0.688224    0.000000
# 14    1.000000    0.824529    0.491230
# 15    0.454574    0.629618    0.103623
# 16    0.278749    0.204373    0.400897
# 17    0.235575    0.100236    0.292001
# 18    0.437443    0.433317    0.341612
# 19    0.338483    0.000000    0.442355
# 20    0.075416    0.012961    0.243367
# 21    0.098508    0.158419    0.222053
# 22    0.378342    0.578158    0.295406
# 23    0.438639    0.432487    0.327569
# 24    0.467984    1.000000    1.000000
# Cluster labels: [1 0 0 0 1 0 3 2 0 0 1 0 3 0 2 0 1 1 0 1 1 1 0 0 2]
# Clustering Report for function: function_3, method: kmean, n_clusters: 4
#
# 📊 **Cluster Analysis Summary**
# ==================================
#
# 🔹 Cluster 0 — background region
#    -----------------------------
#    Size:            12
#    Mean output:     -0.075928
#    Max output:      -0.020404
#    Min output:      -0.131461
#    Variability:     0.001652
#
# 🔹 Cluster 1 — background region
#    -----------------------------
#    Size:            8
#    Mean output:     -0.084765
#    Max output:      -0.030680
#    Min output:      -0.148291
#    Variability:     0.002090
#
# 🔹 Cluster 2 — background region
#    -----------------------------
#    Size:            3
#    Mean output:     -0.307339
#    Max output:      -0.056758
#    Min output:      -0.751389
#    Variability:     0.148701
#
# 🔹 Cluster 3 — background region
#    -----------------------------
#    Size:            2
#    Mean output:     -0.258487
#    Max output:      -0.118048
#    Min output:      -0.398926
#    Variability:     0.039446
#
# 🌟 **Best Cluster Identified**
# ----------------------------------
# Cluster 0 → background region
# Data:
#      compound-1  compound-2  compound-3  trans-side-effect
# 0     0.171525    0.343917    0.248737          -0.112122
# 1     0.242114    0.644074    0.272433          -0.087963
# 2     0.534906    0.398501    0.173389          -0.111415
# 3     0.492581    0.611593    0.340176          -0.034835
# 4     0.134622    0.219917    0.458206          -0.048008
# 5     0.345523    0.941360    0.269363          -0.110621
# 6     0.151837    0.439991    0.990882          -0.398926
# 7     0.645503    0.397143    0.919771          -0.113869
# 8     0.746912    0.284196    0.226300          -0.131461
# 9     0.170477    0.697032    0.149169          -0.094190
# 10    0.220549    0.297825    0.343555          -0.046947
# 11    0.666014    0.671985    0.246295          -0.105965
# 12    0.046809    0.231360    0.770618          -0.118048
# 13    0.600097    0.725136    0.066089          -0.036378
# 14    0.965995    0.861120    0.566829          -0.056758
# 15    0.464647    0.666667    0.171718          -0.111186
# 16    0.303031    0.242424    0.474748          -0.030680
# 17    0.263346    0.138532    0.363743          -0.048179
# 18    0.448900    0.470829    0.414315          -0.020404
# 19    0.357938    0.038532    0.517008          -0.117539
# 20    0.116130    0.051462    0.314168          -0.148291
# 21    0.137356    0.196578    0.292441          -0.126356
# 22    0.394576    0.615328    0.367214          -0.037692
# 23    0.450000    0.470000    0.400000          -0.029032
# 24    0.476973    1.036177    1.085450          -0.751389
# Scaled data:
#      compound-1  compound-2  compound-3
# 0     0.135681    0.306106    0.179179
# 1     0.212477    0.606972    0.202425
# 2     0.531010    0.360819    0.105262
# 3     0.484964    0.574414    0.268882
# 4     0.095533    0.181813    0.384670
# 5     0.324977    0.904959    0.199414
# 6     0.114262    0.402406    0.907228
# 7     0.651331    0.359457    0.837468
# 8     0.761655    0.246244    0.157168
# 9     0.134541    0.660055    0.081503
# 10    0.189016    0.259905    0.272197
# 11    0.673645    0.634948    0.176784
# 12    0.000000    0.193283    0.691147
# 13    0.601933    0.688224    0.000000
# 14    1.000000    0.824529    0.491230
# 15    0.454574    0.629618    0.103623
# 16    0.278749    0.204373    0.400897
# 17    0.235575    0.100236    0.292001
# 18    0.437443    0.433317    0.341612
# 19    0.338483    0.000000    0.442355
# 20    0.075416    0.012961    0.243367
# 21    0.098508    0.158419    0.222053
# 22    0.378342    0.578158    0.295406
# 23    0.438639    0.432487    0.327569
# 24    0.467984    1.000000    1.000000
# Cluster labels: [0 1 1 1 0 1 0 2 1 1 0 1 0 1 2 1 0 0 1 0 0 0 1 1 2]
# Clustering Report for function: function_3, method: hierarchical, n_clusters: 3
#
# 📊 **Cluster Analysis Summary**
# ==================================
#
# 🔹 Cluster 0 — background region
#    -----------------------------
#    Size:            10
#    Mean output:     -0.119510
#    Max output:      -0.030680
#    Min output:      -0.398926
#    Variability:     0.011374
#
# 🔹 Cluster 1 — background region
#    -----------------------------
#    Size:            12
#    Mean output:     -0.075928
#    Max output:      -0.020404
#    Min output:      -0.131461
#    Variability:     0.001652
#
# 🔹 Cluster 2 — background region
#    -----------------------------
#    Size:            3
#    Mean output:     -0.307339
#    Max output:      -0.056758
#    Min output:      -0.751389
#    Variability:     0.148701
#
# 🌟 **Best Cluster Identified**
# ----------------------------------
# Cluster 1 → background region
# Data:
#      compound-1  compound-2  compound-3  trans-side-effect
# 0     0.171525    0.343917    0.248737          -0.112122
# 1     0.242114    0.644074    0.272433          -0.087963
# 2     0.534906    0.398501    0.173389          -0.111415
# 3     0.492581    0.611593    0.340176          -0.034835
# 4     0.134622    0.219917    0.458206          -0.048008
# 5     0.345523    0.941360    0.269363          -0.110621
# 6     0.151837    0.439991    0.990882          -0.398926
# 7     0.645503    0.397143    0.919771          -0.113869
# 8     0.746912    0.284196    0.226300          -0.131461
# 9     0.170477    0.697032    0.149169          -0.094190
# 10    0.220549    0.297825    0.343555          -0.046947
# 11    0.666014    0.671985    0.246295          -0.105965
# 12    0.046809    0.231360    0.770618          -0.118048
# 13    0.600097    0.725136    0.066089          -0.036378
# 14    0.965995    0.861120    0.566829          -0.056758
# 15    0.464647    0.666667    0.171718          -0.111186
# 16    0.303031    0.242424    0.474748          -0.030680
# 17    0.263346    0.138532    0.363743          -0.048179
# 18    0.448900    0.470829    0.414315          -0.020404
# 19    0.357938    0.038532    0.517008          -0.117539
# 20    0.116130    0.051462    0.314168          -0.148291
# 21    0.137356    0.196578    0.292441          -0.126356
# 22    0.394576    0.615328    0.367214          -0.037692
# 23    0.450000    0.470000    0.400000          -0.029032
# 24    0.476973    1.036177    1.085450          -0.751389
# Scaled data:
#      compound-1  compound-2  compound-3
# 0     0.135681    0.306106    0.179179
# 1     0.212477    0.606972    0.202425
# 2     0.531010    0.360819    0.105262
# 3     0.484964    0.574414    0.268882
# 4     0.095533    0.181813    0.384670
# 5     0.324977    0.904959    0.199414
# 6     0.114262    0.402406    0.907228
# 7     0.651331    0.359457    0.837468
# 8     0.761655    0.246244    0.157168
# 9     0.134541    0.660055    0.081503
# 10    0.189016    0.259905    0.272197
# 11    0.673645    0.634948    0.176784
# 12    0.000000    0.193283    0.691147
# 13    0.601933    0.688224    0.000000
# 14    1.000000    0.824529    0.491230
# 15    0.454574    0.629618    0.103623
# 16    0.278749    0.204373    0.400897
# 17    0.235575    0.100236    0.292001
# 18    0.437443    0.433317    0.341612
# 19    0.338483    0.000000    0.442355
# 20    0.075416    0.012961    0.243367
# 21    0.098508    0.158419    0.222053
# 22    0.378342    0.578158    0.295406
# 23    0.438639    0.432487    0.327569
# 24    0.467984    1.000000    1.000000
# Cluster labels: [0 1 7 8 0 1 3 6 7 1 0 4 3 4 5 4 0 0 8 0 0 0 8 8 2]
# Clustering Report for function: function_3, method: hierarchical, n_clusters: -1
#
# 📊 **Cluster Analysis Summary**
# ==================================
#
# 🔹 Cluster 0 — background region
#    -----------------------------
#    Size:            8
#    Mean output:     -0.084765
#    Max output:      -0.030680
#    Min output:      -0.148291
#    Variability:     0.002090
#
# 🔹 Cluster 1 — background region
#    -----------------------------
#    Size:            3
#    Mean output:     -0.097591
#    Max output:      -0.087963
#    Min output:      -0.110621
#    Variability:     0.000137
#
# 🔹 Cluster 2 — background region
#    -----------------------------
#    Size:            1
#    Mean output:     -0.751389
#    Max output:      -0.751389
#    Min output:      -0.751389
#    Variability:     nan
#
# 🔹 Cluster 3 — background region
#    -----------------------------
#    Size:            2
#    Mean output:     -0.258487
#    Max output:      -0.118048
#    Min output:      -0.398926
#    Variability:     0.039446
#
# 🔹 Cluster 4 — background region
#    -----------------------------
#    Size:            3
#    Mean output:     -0.084510
#    Max output:      -0.036378
#    Min output:      -0.111186
#    Variability:     0.001744
#
# 🔹 Cluster 5 — background region
#    -----------------------------
#    Size:            1
#    Mean output:     -0.056758
#    Max output:      -0.056758
#    Min output:      -0.056758
#    Variability:     nan
#
# 🔹 Cluster 6 — background region
#    -----------------------------
#    Size:            1
#    Mean output:     -0.113869
#    Max output:      -0.113869
#    Min output:      -0.113869
#    Variability:     nan
#
# 🔹 Cluster 7 — background region
#    -----------------------------
#    Size:            2
#    Mean output:     -0.121438
#    Max output:      -0.111415
#    Min output:      -0.131461
#    Variability:     0.000201
#
# 🔹 Cluster 8 — background region
#    -----------------------------
#    Size:            4
#    Mean output:     -0.030491
#    Max output:      -0.020404
#    Min output:      -0.037692
#    Variability:     0.000058
#
# 🌟 **Best Cluster Identified**
# ----------------------------------
# Cluster 8 → background region
# ({0: {'stats': {'mean': -0.08476534597918003,
#     'max': -0.030680318237259866,
#     'min': -0.1482910205289665,
#     'var': 0.00209041053204215},
#    'semantic_label': 'background region'},
#   1: {'stats': {'mean': -0.09759111140358834,
#     'max': -0.08796286022736445,
#     'min': -0.11062091307282658,
#     'var': 0.00013702474900433327},
#    'semantic_label': 'background region'},
#   2: {'stats': {'mean': -0.751389275062385,
#     'max': -0.751389275062385,
#     'min': -0.751389275062385,
#     'var': nan},
#    'semantic_label': 'background region'},
#   3: {'stats': {'mean': -0.25848688479659404,
#     'max': -0.11804825644688696,
#     'min': -0.3989255131463011,
#     'var': 0.03944601666549429},
#    'semantic_label': 'background region'},
#   4: {'stats': {'mean': -0.08450952604279505,
#     'max': -0.036377828071632486,
#     'min': -0.11118571432117087,
#     'var': 0.0017443091334139178},
#    'semantic_label': 'background region'},
#   5: {'stats': {'mean': -0.05675837155397648,
#     'max': -0.05675837155397648,
#     'min': -0.05675837155397648,
#     'var': nan},
#    'semantic_label': 'background region'},
#   6: {'stats': {'mean': -0.11386851478863991,
#     'max': -0.11386851478863991,
#     'min': -0.11386851478863991,
#     'var': nan},
#    'semantic_label': 'background region'},
#   7: {'stats': {'mean': -0.12143763146834227,
#     'max': -0.111414654295324,
#     'min': -0.13146060864136055,
#     'var': 0.000200920142821691},
#    'semantic_label': 'background region'},
#   8: {'stats': {'mean': -0.030490867163770273,
#     'max': -0.02040441290319508,
#     'min': -0.037692123265023345,
#     'var': 5.819942215216732e-05},
#    'semantic_label': 'background region'}},
#  8)
