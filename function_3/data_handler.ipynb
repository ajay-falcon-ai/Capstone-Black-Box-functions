# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
print(f"Raw Inputs\n: {inputs}")
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)
print(f"Raw Outputs\n: {outputs}")
# Out:
# Raw Inputs
# : [[0.17152521 0.34391687 0.2487372 ]
#  [0.24211446 0.64407427 0.27243281]
#  [0.53490572 0.39850092 0.17338873]
#  [0.49258141 0.61159319 0.34017639]
#  [0.13462167 0.21991724 0.45820622]
#  [0.34552327 0.94135983 0.26936348]
#  [0.15183663 0.43999062 0.99088187]
#  [0.64550284 0.39714294 0.91977134]
#  [0.74691195 0.28419631 0.22629985]
#  [0.17047699 0.6970324  0.14916943]
#  [0.22054934 0.29782524 0.34355534]
#  [0.66601366 0.67198515 0.2462953 ]
#  [0.04680895 0.23136024 0.77061759]
#  [0.60009728 0.72513573 0.06608864]
#  [0.96599485 0.86111969 0.56682913]]
# Raw Outputs
# : [-0.1121222  -0.08796286 -0.11141465 -0.03483531 -0.04800758 -0.11062091
#  -0.39892551 -0.11386851 -0.13146061 -0.09418956 -0.04694741 -0.10596504
#  -0.11804826 -0.03637783 -0.05675837]

# %%
# %run ../plot_functions.ipynb

# %%
# Track sources
source_labels = ['file'] * len(inputs)

# %%
#Append week-1 data.
#Function 3:	[0.464647, 0.666667, 0.171718]
inputs = np.append(inputs, [[0.464647, 0.666667, 0.171718]], axis=0)
#Function 3:	-0.11118571432117087
outputs = np.append(outputs, [-0.11118571432117087], axis=0)

# %%
source_labels.append('week-1')

# %%
#Append week-2 data.
#Function 3:	[0.303031, 0.242424, 0.474748]
inputs = np.append(inputs, [[0.303031, 0.242424, 0.474748]], axis=0)
#Function 3:	-0.030680318237259866
outputs = np.append(outputs, [-0.030680318237259866], axis=0)

# %%
source_labels.append('week-2')

# %%
#Append week-3 data.
#Function 3:	[0.263346, 0.138532, 0.363743]
inputs = np.append(inputs, [[0.263346, 0.138532, 0.363743]], axis=0)
#Function 3:	-0.048179209676502605
outputs = np.append(outputs, [-0.048179209676502605], axis=0)
source_labels.append('week-3')

# %%
#Append week-4 data.
#Function 3:	[0.448900, 0.470829, 0.414315]
inputs = np.append(inputs, [[0.448900, 0.470829, 0.414315]], axis=0)
#Function 3:	-0.02040441290319508
outputs = np.append(outputs, [-0.02040441290319508], axis=0)
source_labels.append('week-4')

# %%
#Append week-5 data.
#Function 3:	[0.357938, 0.038532, 0.517008]
inputs = np.append(inputs, [[0.357938, 0.038532, 0.517008]], axis=0)
#Function 3:	-0.1175388643248932
outputs = np.append(outputs, [-0.1175388643248932], axis=0)
source_labels.append('week-5')

# %%
#Append week-6 data.
#Function 3:	[0.116130, 0.051462, 0.314168]
inputs = np.append(inputs, [[0.116130, 0.051462, 0.314168]], axis=0)
#Function 3:	-0.1482910205289665
outputs = np.append(outputs, [-0.1482910205289665], axis=0)
source_labels.append('week-6')

# %%
# Create DataFrame
df = pd.DataFrame(inputs, columns=['compound-1', 'compound-2', 'compound-3'])
df['trans-side-effect'] = outputs
df['source'] = source_labels

# Sort by transformed-side effect (larger is better)
df_sorted = df.sort_values(by='trans-side-effect', ascending=False)

# Preview
print(df_sorted)
# Out:
#     compound-1  compound-2  compound-3  trans-side-effect  source
# 16    0.303031    0.242424    0.474748          -0.030680  week-2
# 3     0.492581    0.611593    0.340176          -0.034835    file
# 13    0.600097    0.725136    0.066089          -0.036378    file
# 10    0.220549    0.297825    0.343555          -0.046947    file
# 4     0.134622    0.219917    0.458206          -0.048008    file
# 17    0.263346    0.138532    0.363743          -0.048179  week-3
# 14    0.965995    0.861120    0.566829          -0.056758    file
# 1     0.242114    0.644074    0.272433          -0.087963    file
# 9     0.170477    0.697032    0.149169          -0.094190    file
# 11    0.666014    0.671985    0.246295          -0.105965    file
# 5     0.345523    0.941360    0.269363          -0.110621    file
# 15    0.464647    0.666667    0.171718          -0.111186  week-1
# 2     0.534906    0.398501    0.173389          -0.111415    file
# ...

# %%
plot_output_points(df_sorted, scale_factor=10.0, yield_scale_factor=100.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_40549/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
