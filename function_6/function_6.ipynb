# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
#Process data
# %run data_handler.ipynb
# Out:
#        floor     sugar      eggs    butter      milk  flavour-score  source
# 20  0.733334  0.200000  0.666667  0.733334  0.133334      -0.537794  week-1
# 22  0.667597  0.157201  0.738339  0.678368  0.179636      -0.683325  week-3
# 21  0.757576  0.101010  0.707071  0.757576  0.151515      -0.710242  week-2
# 0   0.728186  0.154693  0.732552  0.693997  0.056401      -0.714265    file
# 4   0.618812  0.331802  0.187288  0.756238  0.328835      -0.829237    file
# 17  0.782880  0.536336  0.443284  0.859700  0.010326      -0.935757    file
# 10  0.536797  0.308781  0.411879  0.388225  0.522528      -1.144785    file
# 1   0.242384  0.844100  0.577809  0.679021  0.501953      -1.209955    file
# 6   0.145111  0.896685  0.896322  0.726272  0.236272      -1.233786    file
# 5   0.784958  0.910682  0.708120  0.959225  0.004911      -1.247049    file
# 16  0.432166  0.715618  0.341819  0.705000  0.614962      -1.294247    file
# ...

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.63530589 0.33772346 0.29616303 0.39427345 0.56093624]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.57822024 0.33772346 0.29616303 0.42231471 0.61560497]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.1, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.57822024 0.26002036 0.26695994 0.39427345 0.56093624]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.57822024 0.31182243 0.29616303 0.36623218 0.56093624]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.63530589 0.28592139 0.29616303 0.42231471 0.5882706 ]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.57822024 0.31182243 0.23775686 0.42231471 0.5882706 ]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.57822024 0.26002036 0.26695994 0.42231471 0.5882706 ]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.60676306 0.3636245  0.26695994 0.39427345 0.56093624]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, grid_size=200, dimension=X.shape[1], apply_scaling=True, filter_mode='median')
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Input space dimension: 5
# Points before downsampling: 320000000000
# Points after downsampling: 102400000
# Final grid shape: (102400000, 5)
# Filtered 17519439 candidates near decision boundary (|margin| < 0.2)
# Excluded 84880561 candidates from consideration
# Final grid shape: (17519439, 5)
# Known data volume: 0.04666744663667053
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028238996652560352
# Mean  17519439
# Std   17519439
# Next query point: [0.57822024 0.26002036 0.26695994 0.42231471 0.5882706 ]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.63530589, 0.33772346, 0.29616303, 0.39427345, 0.56093624]), 'score': 0.053930732675020944, 'dim': 5}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.57822024, 0.33772346, 0.29616303, 0.42231471, 0.61560497]), 'score': 0.049518107995333134, 'dim': 5}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.57822024, 0.26002036, 0.26695994, 0.39427345, 0.56093624]), 'score': 0.04442731296696532, 'dim': 5}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.57822024, 0.31182243, 0.29616303, 0.36623218, 0.56093624]), 'score': 1.1055039668421731, 'dim': 5}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.63530589, 0.28592139, 0.29616303, 0.42231471, 0.5882706 ]), 'score': 2.0548266542689007, 'dim': 5}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.57822024, 0.31182243, 0.23775686, 0.42231471, 0.5882706 ]), 'score': 3.036897787445883, 'dim': 5}
# ...

# %%
#add points to dataframe
add_points_to_df(df_sorted, query_results)
pd.set_option('display.max_rows', None)
print(df_sorted)
# Out:
#        floor     sugar      eggs    butter      milk  flavour-score  source
# 20  0.733334  0.200000  0.666667  0.733334  0.133334      -0.537794  week-1
# 22  0.667597  0.157201  0.738339  0.678368  0.179636      -0.683325  week-3
# 21  0.757576  0.101010  0.707071  0.757576  0.151515      -0.710242  week-2
# 0   0.728186  0.154693  0.732552  0.693997  0.056401      -0.714265    file
# 4   0.618812  0.331802  0.187288  0.756238  0.328835      -0.829237    file
# 17  0.782880  0.536336  0.443284  0.859700  0.010326      -0.935757    file
# 10  0.536797  0.308781  0.411879  0.388225  0.522528      -1.144785    file
# 1   0.242384  0.844100  0.577809  0.679021  0.501953      -1.209955    file
# 6   0.145111  0.896685  0.896322  0.726272  0.236272      -1.233786    file
# 5   0.784958  0.910682  0.708120  0.959225  0.004911      -1.247049    file
# 16  0.432166  0.715618  0.341819  0.705000  0.614962      -1.294247    file
# ...

# %%
plot_output_points(df_sorted, scale_factor=20.0, yield_scale_factor=10.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_64771/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
