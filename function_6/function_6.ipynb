# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
#Process data
# %run data_handler.ipynb
# Out:
#        floor     sugar      eggs    butter      milk  flavour-score  source
# 20  0.733334  0.200000  0.666667  0.733334  0.133334      -0.537794  week-1
# 21  0.757576  0.101010  0.707071  0.757576  0.151515      -0.710242  week-2
# 0   0.728186  0.154693  0.732552  0.693997  0.056401      -0.714265    file
# 4   0.618812  0.331802  0.187288  0.756238  0.328835      -0.829237    file
# 17  0.782880  0.536336  0.443284  0.859700  0.010326      -0.935757    file
# ..       ...       ...       ...       ...       ...            ...     ...
# 19  0.126679  0.291470  0.064528  0.680515  0.892819      -1.746882    file
# 11  0.957740  0.235669  0.099146  0.156806  0.071317      -1.912677    file
# 14  0.439344  0.698924  0.426820  0.109476  0.877888      -2.018425    file
# 18  0.921776  0.931871  0.414876  0.595057  0.735626      -2.155768    file
# 8   0.125720  0.862725  0.028544  0.246605  0.751206      -2.571170    file
#
# [22 rows x 7 columns]

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.73473408 0.12469083]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.73473408 0.12469083]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.1, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.73473408 0.12469083]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.6783683  0.12469083]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.79109985 0.069746  ]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.66759676 0.15720109 0.73833907 0.6783683  0.17963566]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.6783683  0.12469083]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.6783683  0.12469083]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1], apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  5
# Dimension of input space: 5
# Each axis has 100 points before downsampling
# Each axis has 20 points after downsampling
# Function will evaluate across: 3200000 points
# Known data volume: 0.04651798647436605
# Grid volume: 1.6525886953720546
# Coverage ratio of known data to grid volume: 0.028148556627935334
# Mean  3200000
# Std   3200000
# Next query point: [0.72497071 0.15720109 0.67963791 0.6783683  0.12469083]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.73473408, 0.12469083]), 'score': 0.5935252044453212, 'dim': 5}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.73473408, 0.12469083]), 'score': 0.5361834452784408, 'dim': 5}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.73473408, 0.12469083]), 'score': 0.46357699676522446, 'dim': 5}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.6783683 , 0.12469083]), 'score': 2.1476046579537664, 'dim': 5}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.79109985, 0.069746  ]), 'score': 2.7746342705882787, 'dim': 5}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.66759676, 0.15720109, 0.73833907, 0.6783683 , 0.17963566]), 'score': 3.5581912358340766, 'dim': 5}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.6783683 , 0.12469083]), 'score': 0.10915915514722495, 'dim': 5}
# {'method': 'EI', 'xi': 0.05, 'kappa': None, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.6783683 , 0.12469083]), 'score': 0.12596389410622844, 'dim': 5}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.72497071, 0.15720109, 0.67963791, 0.6783683 , 0.12469083]), 'score': 0.10915915514722495, 'dim': 5}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 5
# x: [0.667597, 0.157201, 0.738339, 0.678368, 0.179636]
# Score: 3.558191
# {'method': 'UCB',
#  'xi': None,
#  'kappa': 3.0,
#  'x': array([0.66759676, 0.15720109, 0.73833907, 0.6783683 , 0.17963566]),
#  'score': 3.5581912358340766,
#  'dim': 5}

# %%
#add points to dataframe
add_points_to_df(df_sorted, query_results)
pd.set_option('display.max_rows', None)
print(df_sorted)
# Out:
#        floor     sugar      eggs    butter      milk  flavour-score  source
# 20  0.733334  0.200000  0.666667  0.733334  0.133334      -0.537794  week-1
# 21  0.757576  0.101010  0.707071  0.757576  0.151515      -0.710242  week-2
# 0   0.728186  0.154693  0.732552  0.693997  0.056401      -0.714265    file
# 4   0.618812  0.331802  0.187288  0.756238  0.328835      -0.829237    file
# 17  0.782880  0.536336  0.443284  0.859700  0.010326      -0.935757    file
# 10  0.536797  0.308781  0.411879  0.388225  0.522528      -1.144785    file
# 1   0.242384  0.844100  0.577809  0.679021  0.501953      -1.209955    file
# 6   0.145111  0.896685  0.896322  0.726272  0.236272      -1.233786    file
# 5   0.784958  0.910682  0.708120  0.959225  0.004911      -1.247049    file
# 16  0.432166  0.715618  0.341819  0.705000  0.614962      -1.294247    file
# 9   0.757594  0.355831  0.016523  0.434207  0.112433      -1.309116    file
# 13  0.021735  0.428084  0.835939  0.489489  0.511082      -1.356682    file
# 3   0.770620  0.114404  0.046780  0.648324  0.273549      -1.536058    file
# 12  0.629308  0.803484  0.811408  0.045613  0.110624      -1.622839    file
# 2   0.729523  0.748106  0.679775  0.356552  0.671054      -1.672200    file
# 7   0.945069  0.288459  0.978806  0.961656  0.598016      -1.694343    file
# 15  0.258906  0.793678  0.642114  0.196673  0.593103      -1.702558    file
# 19  0.126679  0.291470  0.064528  0.680515  0.892819      -1.746882    file
# 11  0.957740  0.235669  0.099146  0.156806  0.071317      -1.912677    file
# 14  0.439344  0.698924  0.426820  0.109476  0.877888      -2.018425    file
# 18  0.921776  0.931871  0.414876  0.595057  0.735626      -2.155768    file
# 8   0.125720  0.862725  0.028544  0.246605  0.751206      -2.571170    file
# 22  0.724971  0.157201  0.679638  0.734734  0.124691            NaN  week-x
# 23  0.724971  0.157201  0.679638  0.734734  0.124691            NaN  week-x
# 24  0.724971  0.157201  0.679638  0.734734  0.124691            NaN  week-x
# 25  0.724971  0.157201  0.679638  0.678368  0.124691            NaN  week-x
# 26  0.724971  0.157201  0.679638  0.791100  0.069746            NaN  week-x
# 27  0.667597  0.157201  0.738339  0.678368  0.179636            NaN  week-x
# 28  0.724971  0.157201  0.679638  0.678368  0.124691            NaN  week-x
# 29  0.724971  0.157201  0.679638  0.678368  0.124691            NaN  week-x
# 30  0.724971  0.157201  0.679638  0.678368  0.124691            NaN  week-x

# %%
plot_output_points(df_sorted, scale_factor=20.0, yield_scale_factor=10.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_25643/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
