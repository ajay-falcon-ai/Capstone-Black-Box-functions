# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %run ../pca/pca.ipynb
pca("Function_6")
# Out:
# Component 1
# Fraction of total variance explained by this component:0.3970
# Total fraction of variance explained by the first 1 component(s): 0.3970
#
# Component 2
# Fraction of total variance explained by this component:0.2481
# Total fraction of variance explained by the first 2 component(s): 0.6451
#
# Component 3
# Fraction of total variance explained by this component:0.1912
# Total fraction of variance explained by the first 3 component(s): 0.8363
#
# Component 4
# Fraction of total variance explained by this component:0.1006
# Total fraction of variance explained by the first 4 component(s): 0.9369
#
# Component 5
# Fraction of total variance explained by this component:0.0631
# Total fraction of variance explained by the first 5 component(s): 1.0000
