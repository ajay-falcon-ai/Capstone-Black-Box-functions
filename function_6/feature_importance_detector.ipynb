# %% [markdown]
# import numpy as np
# from sklearn.inspection import permutation_importance
# from sklearn.model_selection import train_test_split
# from sklearn.gaussian_process import GaussianProcessRegressor
# from sklearn.gaussian_process.kernels import RBF

# %%
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %%
# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
X = inputs
y = outputs

# %%
kernel = RBF(length_scale=0.1, length_scale_bounds='fixed')
gp = GaussianProcessRegressor(kernel=kernel, alpha=1e-10)
gp.fit(X, y)

for i in range(1,21):
    # Select next query point using Expected Improvement
    # Permutation importance
    result = permutation_importance(gp, X, y, n_repeats=i, random_state=42)
    print(f"Iteration with {i} repeats:")
    # Display results
    for i in range(X.shape[1]):
        print(f"Feature {i}: Mean importance = {result.importances_mean[i]:.4f}")
    print("\n")
# Out:
# Iteration with 1 repeats:
# Feature 0: Mean importance = 9.9891
# Feature 1: Mean importance = 8.2832
# Feature 2: Mean importance = 6.5243
# Feature 3: Mean importance = 5.9902
# Feature 4: Mean importance = 9.5632
#
#
# Iteration with 2 repeats:
# Feature 0: Mean importance = 9.7650
# Feature 1: Mean importance = 7.7440
# Feature 2: Mean importance = 7.0601
# Feature 3: Mean importance = 7.6836
# Feature 4: Mean importance = 8.2122
#
#
# Iteration with 3 repeats:
# Feature 0: Mean importance = 9.0140
# Feature 1: Mean importance = 8.0287
# Feature 2: Mean importance = 7.7181
# Feature 3: Mean importance = 7.5552
# Feature 4: Mean importance = 8.0521
#
#
# Iteration with 4 repeats:
# Feature 0: Mean importance = 8.7173
# Feature 1: Mean importance = 8.1659
# Feature 2: Mean importance = 7.7658
# Feature 3: Mean importance = 7.4222
# Feature 4: Mean importance = 8.5178
#
#
# Iteration with 5 repeats:
# Feature 0: Mean importance = 8.8159
# Feature 1: Mean importance = 7.6501
# ...
