# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
# %run ../plot_functions.ipynb

# %%
# Track sources
source_labels = ['file'] * len(inputs)

# %%
#Append week-1 data.
#Function 6:	[0.733334, 0.200000, 0.666667, 0.733334, 0.133334]
inputs = np.append(inputs, [[0.733334, 0.200000, 0.666667, 0.733334, 0.133334]], axis=0)
#Function 6:	-0.5377942602933444
outputs = np.append(outputs, [-0.5377942602933444], axis=0)

# %%
source_labels.append('week-1')

# %%
#Append week-2 data.
#Function 6:	[0.757576, 0.101010, 0.707071, 0.757576, 0.151515]
inputs = np.append(inputs, [[0.757576, 0.101010, 0.707071, 0.757576, 0.151515]], axis=0)
#Function 6:	-0.7102415173770004
outputs = np.append(outputs, [-0.7102415173770004], axis=0)

# %%
source_labels.append('week-2')

# %%
#Append week-3 data.
#Function 6:	[0.667597, 0.157201, 0.738339, 0.678368, 0.179636]
inputs = np.append(inputs, [[0.667597, 0.157201, 0.738339, 0.678368, 0.179636]], axis=0)
#Function 6:	-0.6833253974004205
outputs = np.append(outputs, [-0.6833253974004205], axis=0)
source_labels.append('week-3')

# %%
#Append week-4 data.
#Function 6:	[0.578220, 0.311822, 0.237757, 0.422315, 0.588271]
inputs = np.append(inputs, [[0.578220, 0.311822, 0.237757, 0.422315, 0.588271]], axis=0)
#Function 6:	-1.4991274726694743
outputs = np.append(outputs, [-1.4991274726694743], axis=0)
source_labels.append('week-4')

# %%
#Append week-5 data.
#Function 6:	[0.501329, 0.211390, 0.390924, 0.970550, 0.015922]
inputs = np.append(inputs, [[0.501329, 0.211390, 0.390924, 0.970550, 0.015922]], axis=0)
#Function 6:	-0.8866184075971868
outputs = np.append(outputs, [-0.8866184075971868], axis=0)
source_labels.append('week-5')

# %%
#Append week-6 data.
#Function 6:	[0.697910, 0.990583, 1.035622, 0.974136, 0.655285]
inputs = np.append(inputs, [[0.697910, 0.990583, 1.035622, 0.974136, 0.655285]], axis=0)
#Function 6:	-2.0390133791009304
outputs = np.append(outputs, [-2.0390133791009304], axis=0)
source_labels.append('week-6')

# %%
#Append week-7 data.
#Function 6:	[0.909574, 1.046923, 0.862744, 0.923652, 0.853835]
inputs = np.append(inputs, [[0.909574, 1.046923, 0.862744, 0.923652, 0.853835]], axis=0)
#Function 6:	-2.3063646975145775
outputs = np.append(outputs, [-2.3063646975145775], axis=0)
source_labels.append('week-7')

# %%
#Append week-8 data.
#Function 6:	[0.650000, 0.200000, 0.700000, 0.700000, 0.150000]
inputs = np.append(inputs, [[0.650000, 0.200000, 0.700000, 0.700000, 0.150000]], axis=0)
#Function 6:	-0.6349274195629477
outputs = np.append(outputs, [-0.6349274195629477], axis=0)
source_labels.append('week-8')

# %%
# Create DataFrame
df = pd.DataFrame(inputs, columns=['floor', 'sugar', 'eggs', 'butter', 'milk'])
df['flavour-score'] = outputs
df['source'] = source_labels

# Sort by transformed-side effect (larger is better)
df_sorted = df.sort_values(by='flavour-score', ascending=False)

# Preview
print(df_sorted)
# Out:
#        floor     sugar      eggs    butter      milk  flavour-score  source
# 20  0.733334  0.200000  0.666667  0.733334  0.133334      -0.537794  week-1
# 22  0.667597  0.157201  0.738339  0.678368  0.179636      -0.683325  week-3
# 21  0.757576  0.101010  0.707071  0.757576  0.151515      -0.710242  week-2
# 0   0.728186  0.154693  0.732552  0.693997  0.056401      -0.714265    file
# 4   0.618812  0.331802  0.187288  0.756238  0.328835      -0.829237    file
# 24  0.501329  0.211390  0.390924  0.970550  0.015922      -0.886618  week-5
# 17  0.782880  0.536336  0.443284  0.859700  0.010326      -0.935757    file
# 10  0.536797  0.308781  0.411879  0.388225  0.522528      -1.144785    file
# 1   0.242384  0.844100  0.577809  0.679021  0.501953      -1.209955    file
# 6   0.145111  0.896685  0.896322  0.726272  0.236272      -1.233786    file
# 5   0.784958  0.910682  0.708120  0.959225  0.004911      -1.247049    file
# ...

# %%
plot_output_points(df_sorted, scale_factor=40.0, yield_scale_factor=10.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_62647/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
