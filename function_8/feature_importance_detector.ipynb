# %%
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %%
# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
X = inputs
y = outputs

# %%
kernel = RBF(length_scale=0.1, length_scale_bounds='fixed')
gp = GaussianProcessRegressor(kernel=kernel, alpha=1e-10)
gp.fit(X, y)

# Permutation importance
result = permutation_importance(gp, X, y, n_repeats=10, random_state=42)

# Display results
for i in range(X.shape[1]):
    print(f"Feature {i}: Mean importance = {result.importances_mean[i]:.4f}")
# Out:
# Feature 0: Mean importance = 49.3127
# Feature 1: Mean importance = 46.1652
# Feature 2: Mean importance = 49.2634
# Feature 3: Mean importance = 45.2015
# Feature 4: Mean importance = 44.7970
# Feature 5: Mean importance = 47.5836
# Feature 6: Mean importance = 45.9232
# Feature 7: Mean importance = 47.2208
