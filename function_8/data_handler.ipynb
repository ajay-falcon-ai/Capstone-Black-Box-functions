# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 20)  # or any number you prefer
pd.set_option('display.max_columns', None)  # show all columns without wrapping

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
# Track sources
source_labels = ['file'] * len(inputs)

# %%
#Append week-1 data.
#Function 8:	[0.000000, 0.125000, 0.000000, 0.000000, 0.375000, 0.750000, 0.500000, 0.875000]
inputs = np.append(inputs, [[0.000000, 0.125000, 0.000000, 0.000000, 0.375000, 0.750000, 0.500000, 0.875000]], axis=0)
#Function 8:	9.5658
outputs = np.append(outputs, [9.5658], axis=0)

# %%
source_labels.append('week-1')

# %%
#Append week-2 data.
#Function 8:	[0.121212, 0.121212, 0.000000, 0.000000, 0.363636, 0.727273, 0.484849, 0.848484]
inputs = np.append(inputs, [[0.121212, 0.121212, 0.000000, 0.000000, 0.363636, 0.727273, 0.484849, 0.848484]], axis=0)
#Function 8:	9.6097592309634
outputs = np.append(outputs, [9.6097592309634], axis=0)

# %%
source_labels.append('week-2')

# %%
# Create DataFrame
df = pd.DataFrame(inputs, columns=['hype-para-1', 'hype-para-2', 'hype-para-3', 'hype-para-4', 'hype-para-5', 'hype-para-6', 'hype-para-7', 'hype-para-8'])
df['output'] = outputs
df['source'] = source_labels

# Sort by transformed-side effect (larger is better)
df_sorted = df.sort_values(by='output', ascending=False)

# Preview
print(df_sorted)
# Out:
#     hype-para-1  hype-para-2  hype-para-3  hype-para-4  hype-para-5  \
# 41     0.121212     0.121212     0.000000     0.000000     0.363636
# 14     0.056447     0.065956     0.022929     0.038786     0.403935
# 40     0.000000     0.125000     0.000000     0.000000     0.375000
# 26     0.192640     0.630677     0.416796     0.490529     0.796086
# 39     0.481245     0.102461     0.219486     0.677322     0.247509
# ..          ...          ...          ...          ...          ...
# 17     0.735904     0.034612     0.728030     0.147427     0.295743
# 24     0.176150     0.293961     0.975680     0.793936     0.923401
# 34     0.964573     0.973980     0.663753     0.662216     0.673122
# 21     0.898887     0.523642     0.876783     0.218696     0.900261
# 9      0.984933     0.699506     0.998885     0.180148     0.580143
#
#     hype-para-6  hype-para-7  hype-para-8    output  source
# 41     0.727273     0.484849     0.848484  9.609759  week-2
# 14     0.801055     0.488307     0.893085  9.598482    file
# 40     0.750000     0.500000     0.875000  9.565800  week-1
# 26     0.654567     0.276241     0.295518  9.344274    file
# 39     0.244341     0.163825     0.715962  9.183005    file
# ..          ...          ...          ...       ...     ...
# 17     0.445117     0.975180     0.374340  6.767963    file
# 24     0.030842     0.803255     0.595898  6.451943    file
# 34     0.905238     0.458875     0.560918  6.402588    file
# 21     0.282766     0.911078     0.472398  5.841067    file
# 9      0.231087     0.490827     0.313683  5.592193    file
#
# [42 rows x 10 columns]
