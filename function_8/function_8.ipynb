# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
#Process data
# %run data_handler.ipynb
# Out:
#     hype-para-1  hype-para-2  hype-para-3  hype-para-4  hype-para-5  \
# 41     0.121212     0.121212     0.000000     0.000000     0.363636
# 14     0.056447     0.065956     0.022929     0.038786     0.403935
# 40     0.000000     0.125000     0.000000     0.000000     0.375000
# 26     0.192640     0.630677     0.416796     0.490529     0.796086
# 39     0.481245     0.102461     0.219486     0.677322     0.247509
# ..          ...          ...          ...          ...          ...
# 17     0.735904     0.034612     0.728030     0.147427     0.295743
# 24     0.176150     0.293961     0.975680     0.793936     0.923401
# 34     0.964573     0.973980     0.663753     0.662216     0.673122
# 21     0.898887     0.523642     0.876783     0.218696     0.900261
# 9      0.984933     0.699506     0.998885     0.180148     0.580143
#
#     hype-para-6  hype-para-7  hype-para-8    output  source
# 41     0.727273     0.484849     0.848484  9.609759  week-2
# 14     0.801055     0.488307     0.893085  9.598482    file
# 40     0.750000     0.500000     0.875000  9.565800  week-1
# 26     0.654567     0.276241     0.295518  9.344274    file
# 39     0.244341     0.163825     0.715962  9.183005    file
# ..          ...          ...          ...       ...     ...
# 17     0.445117     0.975180     0.374340  6.767963    file
# 24     0.030842     0.803255     0.595898  6.451943    file
# 34     0.905238     0.458875     0.560918  6.402588    file
# 21     0.282766     0.911078     0.472398  5.841067    file
# 9      0.231087     0.490827     0.313683  5.592193    file
#
# [42 rows x 10 columns]

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.1, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.18719169 0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.77599173]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Known data volume: 0.00293658069737019
# Grid volume: 3.349577741323394
# Coverage ratio of known data to grid volume: 0.000876701758893934
# Mean  43046721
# Std   43046721
# Next query point: [0.04375096 0.0453056  0.04531945 0.03369525 0.33774092 0.77166279
#  0.4968813  0.91499767]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 0.2837678352136679, 'dim': 8}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 0.26464520931373403, 'dim': 8}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 0.24169963119128668, 'dim': 8}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 2.0215863983547817, 'dim': 8}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.04375096, 0.18719169, 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 2.7354189284978263, 'dim': 8}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.77599173]), 'score': 3.6081449158031518, 'dim': 8}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 0.09941636537224147, 'dim': 8}
# {'method': 'EI', 'xi': 0.05, 'kappa': None, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 0.11207042541922599, 'dim': 8}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#        0.77166279, 0.4968813 , 0.91499767]), 'score': 0.09941636537224147, 'dim': 8}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 8
# x: [0.043751, 0.045306, 0.045319, 0.033695, 0.337741, 0.771663, 0.496881,
#  0.775992]
# Score: 3.608145
# {'method': 'UCB',
#  'xi': None,
#  'kappa': 3.0,
#  'x': array([0.04375096, 0.0453056 , 0.04531945, 0.03369525, 0.33774092,
#         0.77166279, 0.4968813 , 0.77599173]),
#  'score': 3.6081449158031518,
#  'dim': 8}

# %%
#add points to dataframe
add_points_to_df(df_sorted, query_results)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

print(df_sorted)
# Out:
#     hype-para-1  hype-para-2  hype-para-3  hype-para-4  hype-para-5  hype-para-6  hype-para-7  hype-para-8    output  source
# 41     0.121212     0.121212     0.000000     0.000000     0.363636     0.727273     0.484849     0.848484  9.609759  week-2
# 14     0.056447     0.065956     0.022929     0.038786     0.403935     0.801055     0.488307     0.893085  9.598482    file
# 40     0.000000     0.125000     0.000000     0.000000     0.375000     0.750000     0.500000     0.875000  9.565800  week-1
# 26     0.192640     0.630677     0.416796     0.490529     0.796086     0.654567     0.276241     0.295518  9.344274    file
# 39     0.481245     0.102461     0.219486     0.677322     0.247509     0.244341     0.163825     0.715962  9.183005    file
# 22     0.145120     0.119328     0.420888     0.387609     0.155423     0.875172     0.510560     0.728611  9.141639    file
# 19     0.044329     0.013581     0.258198     0.577644     0.051280     0.158563     0.591030     0.077953  9.013075    file
# 12     0.143550     0.937415     0.232325     0.009043     0.414579     0.409325     0.553779     0.205841  8.976554    file
# 25     0.028947     0.028279     0.481372     0.613175     0.672660     0.022113     0.601483     0.524885  8.830745    file
# 23     0.338954     0.566932     0.376751     0.098916     0.659452     0.245548     0.762483     0.732153  8.817558    file
# 4      0.359909     0.249076     0.495997     0.709215     0.114987     0.289207     0.557295     0.593882  8.606117    file
# 5      0.778818     0.003419     0.337983     0.519528     0.820907     0.537247     0.551347     0.660032  8.541748    file
# 35     0.472071     0.168203     0.086428     0.452656     0.480619     0.622439     0.928974     0.112536  8.472936    file
# 2      0.009077     0.811626     0.520520     0.075687     0.265112     0.091652     0.592415     0.367320  8.459482    file
# 31     0.532820     0.862308     0.538267     0.049443     0.719701     0.906706     0.108231     0.525348  8.421759    file
# 3      0.506028     0.653730     0.363411     0.177981     0.093728     0.197425     0.755827     0.292472  8.284008    file
# 32     0.394865     0.331802     0.740754     0.697862     0.737404     0.783777     0.254495     0.871146  8.278062    file
# 15     0.862437     0.482734     0.281869     0.544102     0.887490     0.382655     0.601902     0.476462  8.159983    file
# 28     0.532721     0.833693     0.071399     0.116811     0.730693     0.937376     0.866508     0.127902  8.042213    file
# 36     0.856007     0.638894     0.326192     0.668503     0.240298     0.210299     0.167546     0.963590  7.977685    file
# 8      0.761137     0.854672     0.382124     0.337352     0.689708     0.309853     0.631380     0.041956  7.957875    file
