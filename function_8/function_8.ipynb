# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
print(len(inputs))
print(inputs)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)
print(len(outputs))
print(outputs)
# Out:
# 40
# [[0.60499445 0.29221502 0.90845275 0.35550624 0.20166872 0.57533801
#   0.31031095 0.73428138]
#  [0.17800696 0.56622265 0.99486184 0.21032501 0.32015266 0.70790879
#   0.63538449 0.10713163]
#  [0.00907698 0.81162615 0.52052036 0.07568668 0.26511183 0.09165169
#   0.59241515 0.36732026]
#  [0.50602816 0.65373012 0.36341078 0.17798105 0.0937283  0.19742533
#   0.7558269  0.29247234]
#  [0.35990926 0.24907568 0.49599717 0.70921498 0.11498719 0.28920692
#   0.55729515 0.59388173]
#  [0.77881834 0.0034195  0.33798313 0.51952778 0.82090699 0.53724669
#   0.5513471  0.66003209]
#  [0.90864932 0.0622497  0.23825955 0.76660355 0.13233596 0.99024381
#   0.68806782 0.74249594]
#  [0.58637144 0.88073573 0.74502075 0.54603485 0.00964888 0.74899176
#   0.23090707 0.09791562]
#  [0.76113733 0.85467239 0.38212433 0.33735198 0.68970832 0.30985305
#   0.63137968 0.04195607]
#  [0.9849332  0.69950626 0.9988855  0.18014846 0.58014315 0.23108719
#   0.49082694 0.31368272]
# ...

# %%
#Append week-1 data.
#Function 8:	[0.000000, 0.125000, 0.000000, 0.000000, 0.375000, 0.750000, 0.500000, 0.875000]
inputs = np.append(inputs, [[0.000000, 0.125000, 0.000000, 0.000000, 0.375000, 0.750000, 0.500000, 0.875000]], axis=0)
#Function 8:	9.5658
outputs = np.append(outputs, [9.5658], axis=0)
# Out:
# 41
# [[0.60499445 0.29221502 0.90845275 0.35550624 0.20166872 0.57533801
#   0.31031095 0.73428138]
#  [0.17800696 0.56622265 0.99486184 0.21032501 0.32015266 0.70790879
#   0.63538449 0.10713163]
#  [0.00907698 0.81162615 0.52052036 0.07568668 0.26511183 0.09165169
#   0.59241515 0.36732026]
#  [0.50602816 0.65373012 0.36341078 0.17798105 0.0937283  0.19742533
#   0.7558269  0.29247234]
#  [0.35990926 0.24907568 0.49599717 0.70921498 0.11498719 0.28920692
#   0.55729515 0.59388173]
#  [0.77881834 0.0034195  0.33798313 0.51952778 0.82090699 0.53724669
#   0.5513471  0.66003209]
#  [0.90864932 0.0622497  0.23825955 0.76660355 0.13233596 0.99024381
#   0.68806782 0.74249594]
#  [0.58637144 0.88073573 0.74502075 0.54603485 0.00964888 0.74899176
#   0.23090707 0.09791562]
#  [0.76113733 0.85467239 0.38212433 0.33735198 0.68970832 0.30985305
#   0.63137968 0.04195607]
#  [0.9849332  0.69950626 0.9988855  0.18014846 0.58014315 0.23108719
#   0.49082694 0.31368272]
# ...

# %%
#Append week-2 data.
#Function 8:	[0.121212, 0.121212, 0.000000, 0.000000, 0.363636, 0.727273, 0.484849, 0.848484]
inputs = np.append(inputs, [[0.121212, 0.121212, 0.000000, 0.000000, 0.363636, 0.727273, 0.484849, 0.848484]], axis=0)
#Function 8:	9.6097592309634
outputs = np.append(outputs, [9.6097592309634], axis=0)

# %%
print(len(inputs))
print(inputs)
print(len(outputs))
print(outputs)

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.72727273
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.1, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.12121212 0.12121212 0.         0.         0.36363636 0.72727273
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1] + 4, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  8
# Dimension of input space: 8
# Each axis has 100 points before downsampling
# Each axis has 9 points after downsampling
# Function will evaluate across: 43046721 points
# Mean  43046721
# Std   43046721
# Next query point: [0.         0.12121212 0.         0.         0.36363636 0.84848485
#  0.48484848 0.84848485]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.        , 0.12121212, 0.        , 0.        , 0.36363636,
#        0.72727273, 0.48484848, 0.84848485]), 'score': np.float64(0.24127031810199118), 'dim': 8}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.        , 0.12121212, 0.        , 0.        , 0.36363636,
#        0.84848485, 0.48484848, 0.84848485]), 'score': np.float64(0.2229358821186695), 'dim': 8}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.        , 0.12121212, 0.        , 0.        , 0.36363636,
#        0.84848485, 0.48484848, 0.84848485]), 'score': np.float64(0.20435375896906083), 'dim': 8}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.        , 0.12121212, 0.        , 0.        , 0.36363636,
#        0.84848485, 0.48484848, 0.84848485]), 'score': np.float64(2.024030517393923), 'dim': 8}
# ...
