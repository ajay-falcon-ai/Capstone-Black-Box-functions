# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %run ../pca/pca.ipynb
pca("Function_8")
# Out:
# Component 1
# Fraction of total variance explained by this component:0.2372
# Total fraction of variance explained by the first 1 component(s): 0.2372
#
# Component 2
# Fraction of total variance explained by this component:0.1595
# Total fraction of variance explained by the first 2 component(s): 0.3968
#
# Component 3
# Fraction of total variance explained by this component:0.1396
# Total fraction of variance explained by the first 3 component(s): 0.5364
#
# Component 4
# Fraction of total variance explained by this component:0.1327
# Total fraction of variance explained by the first 4 component(s): 0.6691
#
# Component 5
# Fraction of total variance explained by this component:0.1273
# Total fraction of variance explained by the first 5 component(s): 0.7964
#
# Component 6
# Fraction of total variance explained by this component:0.0830
# Total fraction of variance explained by the first 6 component(s): 0.8794
#
# Component 7
# ...
