# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %run ../pca/pca.ipynb
pca("Function_4")
# Out:
# Component 1
# Fraction of total variance explained by this component:0.3460
# Total fraction of variance explained by the first 1 component(s): 0.3460
#
# Component 2
# Fraction of total variance explained by this component:0.2845
# Total fraction of variance explained by the first 2 component(s): 0.6305
#
# Component 3
# Fraction of total variance explained by this component:0.2076
# Total fraction of variance explained by the first 3 component(s): 0.8381
#
# Component 4
# Fraction of total variance explained by this component:0.1619
# Total fraction of variance explained by the first 4 component(s): 1.0000
