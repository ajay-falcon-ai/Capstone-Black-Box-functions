# %%
import numpy as np

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
print(len(inputs))
print(inputs)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)
print(len(outputs))
print(outputs)
# Out:
# 30
# [[0.89698105 0.72562797 0.17540431 0.70169437]
#  [0.8893564  0.49958786 0.53926886 0.50878344]
#  [0.25094624 0.03369313 0.14538002 0.49493242]
#  [0.34696206 0.0062504  0.76056361 0.61302356]
#  [0.12487118 0.12977019 0.38440048 0.2870761 ]
#  [0.80130271 0.50023109 0.70664456 0.19510284]
#  [0.24770826 0.06044543 0.04218635 0.44132425]
#  [0.74670224 0.7570915  0.36935306 0.20656628]
#  [0.40066503 0.07257425 0.88676825 0.24384229]
#  [0.6260706  0.58675126 0.43880578 0.77885769]
#  [0.95713529 0.59764438 0.76611385 0.77620991]
#  [0.73281243 0.14524998 0.47681272 0.13336573]
#  [0.65511548 0.07239183 0.68715175 0.08151656]
#  [0.21973443 0.83203134 0.48286416 0.08256923]
#  [0.48859419 0.2119651  0.93917791 0.37619173]
#  [0.16713049 0.87655456 0.21723954 0.95980098]
#  [0.21691119 0.16608583 0.24137226 0.77006248]
#  [0.38748784 0.80453226 0.75179548 0.72382744]
#  [0.98562189 0.66693268 0.15678328 0.8565348 ]
#  [0.03782483 0.66485335 0.16198218 0.25392378]
#  [0.68348638 0.9027701  0.33541983 0.99948256]
#  [0.17034731 0.75695908 0.27652049 0.5312315 ]
#  [0.85965692 0.91959232 0.20613873 0.09779683]
#  [0.28213837 0.50598691 0.53053084 0.09630162]
#  [0.32607578 0.4723669  0.453192   0.10588734]
#  [0.94838936 0.89451301 0.85163782 0.55219629]
#  [0.66495539 0.04656628 0.11677747 0.79371778]
#  [0.57776561 0.42877174 0.42582587 0.24900741]
#  [0.73861301 0.48210263 0.70936644 0.50397001]
#  [0.8548108  0.49396462 0.73530997 0.80809201]]
# 30
# [-22.10828779 -14.60139663 -11.69993246 -16.05376511 -10.06963343
#  -15.48708254 -12.68168498 -16.02639977 -17.04923465 -12.74176599
#  -27.31639636 -13.52764887 -16.6791152  -16.50715856 -17.81799934
#  -26.56182083 -12.75832422 -19.44155762 -28.90327367 -13.70274694
#  -29.4270914  -11.56574199 -26.85778644  -7.96677535  -6.70208925
#  -32.62566022 -19.98949793  -4.02554228 -13.12278233 -23.1394284 ]

# %%
def print_csv(arr):
    """
    Print a NumPy array as CSV:
    - One row per line
    - Comma-separated columns
    - If there's only one row, print each value on a new line
    """
    arr = np.asarray(arr)

    if arr.ndim == 0:
        # Scalar
        print(str(arr.item()))

    elif arr.ndim == 1:
        # 1D: treat as single row → print each value on its own line
        for val in arr:
            print(str(val))

    elif arr.ndim == 2:
        if arr.shape[0] == 1:
            # Single row → print each column value on its own line
            for val in arr[0]:
                print(str(val))
        else:
            # Multiple rows → print comma-separated
            for row in arr:
                print(','.join(map(str, row)))

    else:
        # 3D+ → flatten each leading slice to a row
        reshaped = arr.reshape(arr.shape[0], -1)
        for row in reshaped:
            print(','.join(map(str, row)))
print_csv(inputs)
print_csv(outputs)
# Out:
# 0.8969810543559719,0.7256279703482243,0.17540430890241154,0.7016943693717497
# 0.8893563957199797,0.49958785537696504,0.5392688577643431,0.5087834390633533
# 0.25094624275233424,0.03369313054735357,0.14538002473552147,0.49493242056497855
# 0.34696206091432413,0.006250400244917853,0.7605636064368956,0.6130235572343078
# 0.1248711812207095,0.12977019306510673,0.38440048300130336,0.28707610106061277
# 0.8013027073487429,0.5002310937156627,0.7066445599562093,0.19510284101191622
# 0.2477082618994807,0.060445427321989764,0.04218634513719777,0.44132425054403157
# 0.7467022420948025,0.7570915044306501,0.3693530595537917,0.20656628103766395
# 0.400665027194423,0.07257425107127335,0.8867682538447798,0.24384228978922717
# 0.6260705961944015,0.5867512592598441,0.4388057821707446,0.7788576937904925
# 0.9571352930644363,0.5976443830130996,0.7661138515714809,0.7762099053238541
# 0.7328124260168783,0.14524997897358805,0.47681271763115285,0.13336573404584584
# 0.6551154792459779,0.07239182690482326,0.6871517458198465,0.08151656419033015
# 0.21973442915914299,0.8320313351480582,0.4828641624528299,0.08256923057524457
# 0.48859418950356637,0.2119650955674609,0.9391779073552307,0.37619172590371996
# 0.16713048556058774,0.8765545582566224,0.21723954496692865,0.9598009845510594
# 0.21691118811255716,0.16608582897898938,0.24137225639083593,0.7700624756956358
# 0.38748783671725395,0.8045322581845359,0.7517954827501873,0.7238274385488449
# 0.9856218929694016,0.6669326785131365,0.15678328252958762,0.8565348006982442
# 0.03782482853334601,0.6648533464557935,0.1619821750221554,0.2539237802262948
# 0.6834863848727072,0.9027701030814779,0.3354198256002018,0.9994825612275692
# 0.1703473054043091,0.7569590826298485,0.2765204860603998,0.5312314975365982
# 0.8596569193380881,0.9195923219593923,0.2061387278543615,0.09779683100452252
# 0.28213836819277516,0.5059869120612994,0.5305308425014074,0.09630162301775336
# 0.3260757847990565,0.47236690365870715,0.45319199560129586,0.10588733843025877
# 0.9483893624466845,0.8945130079782345,0.8516378174441099,0.5521962863978067
# 0.6649553897315406,0.04656627674464964,0.11677746938768019,0.7937177796214518
# 0.5777656143780968,0.4287717415443063,0.4258258674882194,0.24900741466191134
# 0.7386130139763387,0.48210263436120226,0.7093664425017454,0.503970013890856
# 0.854810796763389,0.4939646196379057,0.7353099749980351,0.808092012668331
# -22.108287785435817
# -14.601396631953161
# -11.699932463834426
# -16.053765110568296
# -10.069633426012889
# -15.487082537755288
# -12.68168497681565
# -16.02639976898352
# -17.049234647535723
# -12.741765988316185
# -27.316396356142608
# -13.527648872277506
# -16.679115197479913
# -16.50715856428234
# -17.81799933882949
# -26.561820829779602
# -12.758324216781741
# -19.441557624451722
# -28.90327367383377
# -13.702746938161251
# -29.427091401989347
# -11.565741989583191
# -26.857786437773637
# -7.9667753510303925
# -6.702089254839066
# -32.625660215962455
# -19.98949792679556
# -4.025542281908162
# -13.122782331852594
# -23.139428397634813
