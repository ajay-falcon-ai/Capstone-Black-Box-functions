# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
# %run ../plot_functions.ipynb

# %%
# Track sources
source_labels = ['file'] * len(inputs)

# %%
#Append week-1 data.
#Function 4:	[0.469388, 0.448980, 0.469388, 0.204082]
inputs = np.append(inputs, [[0.469388, 0.448980, 0.469388, 0.204082]], axis=0)
#Function 4:	-4.620232320523549
outputs = np.append(outputs, [-4.620232320523549], axis=0)

# %%
source_labels.append('week-1')

# %%
#Append week-2 data.
#Function 4:	[0.515152, 0.484848, 0.363636, 0.181819]
inputs = np.append(inputs, [[0.515152, 0.484848, 0.363636, 0.181819]], axis=0)
#Function 4:	-4.939960051262183
outputs = np.append(outputs, [-4.939960051262183], axis=0)

# %%
source_labels.append('week-2')

# %%
#Append week-3 data.
#Function 4:	[0.529114, 0.378577, 0.407577, 0.150905]
inputs = np.append(inputs, [[0.515152, 0.484848, 0.363636, 0.181819]], axis=0)
#Function 4:	-5.313374447160626
outputs = np.append(outputs, [-5.313374447160626], axis=0)
source_labels.append('week-3')

# %%
#Append week-4 data.
#Function 4:	[0.111733, 0.041201, 0.540545, 0.286416]
inputs = np.append(inputs, [[0.111733, 0.041201, 0.540545, 0.286416]], axis=0)
#Function 4:	-12.867749036987885
outputs = np.append(outputs, [-12.867749036987885], axis=0)
source_labels.append('week-4')

# %%
#Append week-5 data.
#Function 4:	[0.343612, 0.592249, 0.651353, 0.444513]
inputs = np.append(inputs, [[0.343612, 0.592249, 0.651353, 0.444513]], axis=0)
#Function 4:	-7.221570128386034
outputs = np.append(outputs, [-7.221570128386034], axis=0)
source_labels.append('week-5')

# %%
#Append week-6 data.
#Function 4:	[0.445393, 0.174795, 0.339088, 0.116347]
inputs = np.append(inputs, [[0.445393, 0.174795, 0.339088, 0.116347]], axis=0)
#Function 4:	-7.6005772787938355
outputs = np.append(outputs, [-7.6005772787938355], axis=0)
source_labels.append('week-6')

# %%
# Create DataFrame
df = pd.DataFrame(inputs, columns=['hype-para-1', 'hype-para-2', 'hype-para-3', 'hype-para-4'])
df['opt-place-score'] = outputs
df['source'] = source_labels

# Sort by transformed-side effect (larger is better)
df_sorted = df.sort_values(by='opt-place-score', ascending=False)

# Preview
print(df_sorted)
# Out:
#     hype-para-1  hype-para-2  hype-para-3  hype-para-4  opt-place-score  source
# 27     0.577766     0.428772     0.425826     0.249007        -4.025542    file
# 30     0.469388     0.448980     0.469388     0.204082        -4.620232  week-1
# 31     0.515152     0.484848     0.363636     0.181819        -4.939960  week-2
# 32     0.515152     0.484848     0.363636     0.181819        -5.313374  week-3
# 24     0.326076     0.472367     0.453192     0.105887        -6.702089    file
# 23     0.282138     0.505987     0.530531     0.096302        -7.966775    file
# 4      0.124871     0.129770     0.384400     0.287076       -10.069633    file
# 21     0.170347     0.756959     0.276520     0.531231       -11.565742    file
# 2      0.250946     0.033693     0.145380     0.494932       -11.699932    file
# 6      0.247708     0.060445     0.042186     0.441324       -12.681685    file
# 9      0.626071     0.586751     0.438806     0.778858       -12.741766    file
# ...

# %%
plot_output_points(df_sorted, scale_factor=20.0, yield_scale_factor=1.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_40826/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
