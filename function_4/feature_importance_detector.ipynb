# %%
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %%
# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
X = inputs
y = outputs

# %%
kernel = RBF(length_scale=0.1, length_scale_bounds='fixed')
gp = GaussianProcessRegressor(kernel=kernel, alpha=1e-10)
gp.fit(X, y)

for i in range(1,21):
    # Select next query point using Expected Improvement
    # Permutation importance
    result = permutation_importance(gp, X, y, n_repeats=i, random_state=42)
    print(f"Iteration with {i} repeats:")
    # Display results
    for i in range(X.shape[1]):
        print(f"Feature {i}: Mean importance = {result.importances_mean[i]:.4f}")
    print("\n")
# Out:
# Iteration with 1 repeats:
# Feature 0: Mean importance = 3.8745
# Feature 1: Mean importance = 4.0622
# Feature 2: Mean importance = 4.2479
# Feature 3: Mean importance = 4.1006
#
#
# Iteration with 2 repeats:
# Feature 0: Mean importance = 4.0070
# Feature 1: Mean importance = 4.5938
# Feature 2: Mean importance = 4.3201
# Feature 3: Mean importance = 4.6395
#
#
# Iteration with 3 repeats:
# Feature 0: Mean importance = 4.0814
# Feature 1: Mean importance = 4.2027
# Feature 2: Mean importance = 4.0032
# Feature 3: Mean importance = 4.5465
#
#
# Iteration with 4 repeats:
# Feature 0: Mean importance = 4.0799
# Feature 1: Mean importance = 4.2708
# Feature 2: Mean importance = 4.1802
# Feature 3: Mean importance = 4.6958
#
#
# Iteration with 5 repeats:
# Feature 0: Mean importance = 4.1493
# Feature 1: Mean importance = 4.3840
# Feature 2: Mean importance = 4.0680
# Feature 3: Mean importance = 4.6078
#
#
# Iteration with 6 repeats:
# Feature 0: Mean importance = 4.0809
# Feature 1: Mean importance = 4.2473
# Feature 2: Mean importance = 4.0706
# Feature 3: Mean importance = 4.4736
#
#
# Iteration with 7 repeats:
# Feature 0: Mean importance = 4.1234
# Feature 1: Mean importance = 4.3422
# Feature 2: Mean importance = 4.0762
# Feature 3: Mean importance = 4.4839
#
#
# Iteration with 8 repeats:
# Feature 0: Mean importance = 4.1014
# Feature 1: Mean importance = 4.3956
# Feature 2: Mean importance = 4.2170
# Feature 3: Mean importance = 4.3600
#
#
# Iteration with 9 repeats:
# Feature 0: Mean importance = 4.1965
# Feature 1: Mean importance = 4.3418
# Feature 2: Mean importance = 4.2199
# Feature 3: Mean importance = 4.2722
#
#
# Iteration with 10 repeats:
# Feature 0: Mean importance = 4.1607
# Feature 1: Mean importance = 4.1810
# Feature 2: Mean importance = 4.2986
# Feature 3: Mean importance = 4.2606
#
#
# Iteration with 11 repeats:
# Feature 0: Mean importance = 4.1985
# Feature 1: Mean importance = 4.2910
# Feature 2: Mean importance = 4.2463
# Feature 3: Mean importance = 4.2894
#
#
# Iteration with 12 repeats:
# Feature 0: Mean importance = 4.2484
# Feature 1: Mean importance = 4.3735
# Feature 2: Mean importance = 4.2509
# Feature 3: Mean importance = 4.2933
#
#
# Iteration with 13 repeats:
# Feature 0: Mean importance = 4.2530
# Feature 1: Mean importance = 4.3371
# Feature 2: Mean importance = 4.2376
# Feature 3: Mean importance = 4.3044
#
#
# Iteration with 14 repeats:
# Feature 0: Mean importance = 4.2562
# Feature 1: Mean importance = 4.3204
# Feature 2: Mean importance = 4.1849
# Feature 3: Mean importance = 4.3089
#
#
# Iteration with 15 repeats:
# Feature 0: Mean importance = 4.2316
# Feature 1: Mean importance = 4.3832
# Feature 2: Mean importance = 4.1569
# Feature 3: Mean importance = 4.3415
#
#
# Iteration with 16 repeats:
# Feature 0: Mean importance = 4.2207
# Feature 1: Mean importance = 4.4324
# Feature 2: Mean importance = 4.1924
# Feature 3: Mean importance = 4.3479
#
#
# Iteration with 17 repeats:
# Feature 0: Mean importance = 4.1707
# Feature 1: Mean importance = 4.3982
# Feature 2: Mean importance = 4.1712
# Feature 3: Mean importance = 4.2926
#
#
# Iteration with 18 repeats:
# Feature 0: Mean importance = 4.2241
# Feature 1: Mean importance = 4.3945
# Feature 2: Mean importance = 4.1943
# Feature 3: Mean importance = 4.2562
#
#
# Iteration with 19 repeats:
# Feature 0: Mean importance = 4.1650
# Feature 1: Mean importance = 4.4235
# Feature 2: Mean importance = 4.1502
# Feature 3: Mean importance = 4.2146
#
#
# Iteration with 20 repeats:
# Feature 0: Mean importance = 4.1479
# Feature 1: Mean importance = 4.3286
# Feature 2: Mean importance = 4.1613
# Feature 3: Mean importance = 4.2396
