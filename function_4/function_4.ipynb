# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler

# %%
#Process data
# %run data_handler.ipynb
# Out:
#     hype-para-1  hype-para-2  hype-para-3  hype-para-4  opt-place-score  \
# 27     0.577766     0.428772     0.425826     0.249007        -4.025542
# 30     0.469388     0.448980     0.469388     0.204082        -4.620232
# 31     0.515152     0.484848     0.363636     0.181819        -4.939960
# 24     0.326076     0.472367     0.453192     0.105887        -6.702089
# 23     0.282138     0.505987     0.530531     0.096302        -7.966775
#
#     source
# 27    file
# 30  week-1
# 31  week-2
# 24    file
# 23    file

# %%
X = inputs
y = outputs

# %%
# %run ../common_functions.ipynb
# Initialize result collection
query_results = []

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.01, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.44605254 0.4075767  0.21866087]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.05, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.05, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.44605254 0.4075767  0.21866087]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='PI', xi=0.1, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('PI', 0.1, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.44605254 0.4075767  0.21866087]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=1.0, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 1.0, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.41231491 0.4075767  0.18478311]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=2.0, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 2.0, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.37857728 0.4075767  0.18478311]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='UCB', kappa=3.0, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('UCB', 3.0, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.37857728 0.4075767  0.15090535]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.44605254 0.4075767  0.21866087]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.05, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.05, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.44605254 0.4075767  0.21866087]

# %%
next_point, acq_vals, grid = select_next_query_multi(X, y, method='EI', xi=0.1, dimension=X.shape[1] - 1, apply_scaling=True)
print("Next query point:", next_point)
score = acq_vals[np.argmax(acq_vals)]
log_query_candidate('EI', 0.1, next_point,score)
# Out:
# Number of features:  4
# Dimension of input space: 4
# Each axis has 100 points before downsampling
# Each axis has 34 points after downsampling
# Function will evaluate across: 1336336 points
# Known data volume: 0.19209942612363415
# Grid volume: 1.5672040804233487
# Coverage ratio of known data to grid volume: 0.12257460819763968
# Mean  1336336
# Std   1336336
# Next query point: [0.52911423 0.44605254 0.4075767  0.21866087]

# %%
find_best_candidate(query_results)
# Out:
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.52911423, 0.44605254, 0.4075767 , 0.21866087]), 'score': 0.7693566911148684, 'dim': 4}
# {'method': 'PI', 'xi': 0.05, 'kappa': None, 'x': array([0.52911423, 0.44605254, 0.4075767 , 0.21866087]), 'score': 0.7221018517030677, 'dim': 4}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.52911423, 0.44605254, 0.4075767 , 0.21866087]), 'score': 0.6570978869391342, 'dim': 4}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.52911423, 0.41231491, 0.4075767 , 0.18478311]), 'score': 2.2012195116254887, 'dim': 4}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.52911423, 0.37857728, 0.4075767 , 0.18478311]), 'score': 2.805442936971035, 'dim': 4}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.52911423, 0.37857728, 0.4075767 , 0.15090535]), 'score': 3.5928351771358042, 'dim': 4}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.52911423, 0.44605254, 0.4075767 , 0.21866087]), 'score': 0.17162241619540686, 'dim': 4}
# {'method': 'EI', 'xi': 0.05, 'kappa': None, 'x': array([0.52911423, 0.44605254, 0.4075767 , 0.21866087]), 'score': 0.206127210872555, 'dim': 4}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.52911423, 0.44605254, 0.4075767 , 0.21866087]), 'score': 0.17162241619540686, 'dim': 4}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 4
# x: [0.529114, 0.378577, 0.407577, 0.150905]
# Score: 3.592835
# {'method': 'UCB',
#  'xi': None,
#  'kappa': 3.0,
#  'x': array([0.52911423, 0.37857728, 0.4075767 , 0.15090535]),
#  'score': 3.5928351771358042,
#  'dim': 4}

# %%
#add points to dataframe
add_points_to_df(df_sorted, query_results)
pd.set_option('display.max_rows', None)
print(df_sorted)
# Out:
#     hype-para-1  hype-para-2  hype-para-3  hype-para-4  opt-place-score  \
# 27     0.577766     0.428772     0.425826     0.249007        -4.025542
# 30     0.469388     0.448980     0.469388     0.204082        -4.620232
# 31     0.515152     0.484848     0.363636     0.181819        -4.939960
# 24     0.326076     0.472367     0.453192     0.105887        -6.702089
# 23     0.282138     0.505987     0.530531     0.096302        -7.966775
# 4      0.124871     0.129770     0.384400     0.287076       -10.069633
# 21     0.170347     0.756959     0.276520     0.531231       -11.565742
# 2      0.250946     0.033693     0.145380     0.494932       -11.699932
# 6      0.247708     0.060445     0.042186     0.441324       -12.681685
# 9      0.626071     0.586751     0.438806     0.778858       -12.741766
# 16     0.216911     0.166086     0.241372     0.770062       -12.758324
# 28     0.738613     0.482103     0.709366     0.503970       -13.122782
# 11     0.732812     0.145250     0.476813     0.133366       -13.527649
# 19     0.037825     0.664853     0.161982     0.253924       -13.702747
# 1      0.889356     0.499588     0.539269     0.508783       -14.601397
# 5      0.801303     0.500231     0.706645     0.195103       -15.487083
# 7      0.746702     0.757092     0.369353     0.206566       -16.026400
# 3      0.346962     0.006250     0.760564     0.613024       -16.053765
# 13     0.219734     0.832031     0.482864     0.082569       -16.507159
# 12     0.655115     0.072392     0.687152     0.081517       -16.679115
# 8      0.400665     0.072574     0.886768     0.243842       -17.049235
# 14     0.488594     0.211965     0.939178     0.376192       -17.817999
# 17     0.387488     0.804532     0.751795     0.723827       -19.441558
# 26     0.664955     0.046566     0.116777     0.793718       -19.989498
# 0      0.896981     0.725628     0.175404     0.701694       -22.108288
# 29     0.854811     0.493965     0.735310     0.808092       -23.139428
# 15     0.167130     0.876555     0.217240     0.959801       -26.561821
# 22     0.859657     0.919592     0.206139     0.097797       -26.857786
# 10     0.957135     0.597644     0.766114     0.776210       -27.316396
# 18     0.985622     0.666933     0.156783     0.856535       -28.903274
# 20     0.683486     0.902770     0.335420     0.999483       -29.427091
# 25     0.948389     0.894513     0.851638     0.552196       -32.625660
# 32     0.529114     0.446053     0.407577     0.218661              NaN
# 33     0.529114     0.446053     0.407577     0.218661              NaN
# 34     0.529114     0.446053     0.407577     0.218661              NaN
# 35     0.529114     0.412315     0.407577     0.184783              NaN
# 36     0.529114     0.378577     0.407577     0.184783              NaN
# 37     0.529114     0.378577     0.407577     0.150905              NaN
# 38     0.529114     0.446053     0.407577     0.218661              NaN
# 39     0.529114     0.446053     0.407577     0.218661              NaN
# 40     0.529114     0.446053     0.407577     0.218661              NaN
#
#     source
# 27    file
# 30  week-1
# 31  week-2
# 24    file
# 23    file
# 4     file
# 21    file
# 2     file
# 6     file
# 9     file
# 16    file
# 28    file
# 11    file
# 19    file
# 1     file
# 5     file
# 7     file
# 3     file
# 13    file
# 12    file
# 8     file
# 14    file
# 17    file
# 26    file
# 0     file
# 29    file
# 15    file
# 22    file
# 10    file
# 18    file
# 20    file
# 25    file
# 32  week-x
# 33  week-x
# 34  week-x
# 35  week-x
# 36  week-x
# 37  week-x
# 38  week-x
# 39  week-x
# 40  week-x

# %%
plot_output_points(df_sorted, scale_factor=20.0, yield_scale_factor=1.0)
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_25336/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
