# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %run ../pca/pca.ipynb
pca("Function_7")
# Out:
# Component 1
# Fraction of total variance explained by this component:0.2756
# Total fraction of variance explained by the first 1 component(s): 0.2756
#
# Component 2
# Fraction of total variance explained by this component:0.2359
# Total fraction of variance explained by the first 2 component(s): 0.5115
#
# Component 3
# Fraction of total variance explained by this component:0.1883
# Total fraction of variance explained by the first 3 component(s): 0.6999
#
# Component 4
# Fraction of total variance explained by this component:0.1361
# Total fraction of variance explained by the first 4 component(s): 0.8360
#
# Component 5
# Fraction of total variance explained by this component:0.0898
# Total fraction of variance explained by the first 5 component(s): 0.9258
#
# Component 6
# Fraction of total variance explained by this component:0.0742
# Total fraction of variance explained by the first 6 component(s): 1.0000
