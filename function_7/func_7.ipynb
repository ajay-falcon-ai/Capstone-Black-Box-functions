# %%
# flows/function1_flow.py

import sys, os
try:
    # Works when running as a normal Python script
    project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
except NameError:
    # Fallback for Jupyter/IPython where __file__ is not defined
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from data.BaseDataHandler import BaseDataHandler
from optimisation.BayesOptUtils import BayesOptUtils
from plotting.PlotUtils import PlotUtils
from Function7DataHandler import Function7DataHandler  # same folder
from models.SurrogateNN import SurrogateTrainer

# --- Data ---
dh = Function7DataHandler()
dh.add_weekly_updates()
df_sorted = dh.build_dataframe()
X, y = dh.inputs, dh.outputs

# --- Utilities ---
utils = BayesOptUtils()
plotter = PlotUtils()
trainer = SurrogateTrainer(input_dim=X.shape[1], lr=1e-3, epochs=500)

# --- Hyperparameters supplied here ---
xi_values = [0.01, 0.1, 0.3]
kappa_values = [1.0, 2.0, 3.0]
grid_sizes = [100]
methods = ['PI', 'EI', 'UCB']
apply_scaling = True
filter_mode = 'media'

# --- Run flow ---
results = utils.run_flow(
    trainer, X, y,
    xi_values=xi_values,
    kappa_values=kappa_values,
    grid_sizes=grid_sizes,
    methods=methods,
    apply_scaling=apply_scaling,
    filter_mode=filter_mode
)
# Out:
# Epoch 1/500, Train Loss: 1.176174, Val Loss: 0.046633
# Epoch 50/500, Train Loss: 0.649687, Val Loss: 0.131450
# Early stopping at epoch 51, best val_loss=0.046633
# /Users/ajay.amrite/Documents/AI Course/Capstone/Black-Box functions/models/SurrogateNN.py:117: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1711403226260/work/aten/src/ATen/native/ReduceOps.cpp:1760.)
#   "std": param.data.std().item()
# Using 2 dimensions.
# Points before downsampling: 10000
# Points after downsampling: 10000
# Final grid shape: (10000, 2)
# Filtered 219 candidates near decision boundary (|margin| < 0.2)
# Excluded 9781 candidates from consideration
# Final grid shape: (219, 2)
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.01, 'kappa': None, 'x': array([0.46802608, 1.05224389]), 'score': 0.06504932667679428, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.46802608, 1.05224389]), 'score': 0.010147929048563075, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'PI', 'xi': 0.3, 'kappa': None, 'x': array([0.46802608, 1.05224389]), 'score': 1.9406572696037315e-05, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'EI', 'xi': 0.01, 'kappa': None, 'x': array([0.46802608, 1.05224389]), 'score': 0.0031671228649422477, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.46802608, 1.05224389]), 'score': 0.0003840564807631136, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'EI', 'xi': 0.3, 'kappa': None, 'x': array([0.46802608, 1.05224389]), 'score': 4.768995468937945e-07, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.4579111 , 1.05224389]), 'score': 0.23050615962240695, 'dim': 2, 'predicted_y': 0.123334676}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.46802608, 1.05224389]), 'score': 0.34157478465758906, 'dim': 2, 'predicted_y': 0.11855966}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.46802608, 1.05224389]), 'score': 0.4530823477226964, 'dim': 2, 'predicted_y': 0.11855966}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 2
# x: [0.468026, 1.052244]
# Score: 0.453082
# Using 2 dimensions.
# Points before downsampling: 40000
# Points after downsampling: 40000
# Final grid shape: (40000, 2)
# Filtered 1292 candidates near decision boundary (|margin| < 0.2)
# Excluded 38708 candidates from consideration
# Final grid shape: (1292, 2)
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.01, 'kappa': None, 'x': array([0.46558628, 1.05278335]), 'score': 0.06683717981185833, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.46558628, 1.05278335]), 'score': 0.010564769109337426, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'PI', 'xi': 0.3, 'kappa': None, 'x': array([0.46558628, 1.05278335]), 'score': 2.096896996621459e-05, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'EI', 'xi': 0.01, 'kappa': None, 'x': array([0.46558628, 1.05278335]), 'score': 0.0032746315592648585, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.46558628, 1.05278335]), 'score': 0.000402185720814934, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'EI', 'xi': 0.3, 'kappa': None, 'x': array([0.46558628, 1.05278335]), 'score': 5.179580507816386e-07, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.46558628, 1.05278335]), 'score': 0.23153728155285325, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.46558628, 1.05278335]), 'score': 0.3432146143513959, 'dim': 2, 'predicted_y': 0.11985995}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.46558628, 1.05278335]), 'score': 0.45489194714993847, 'dim': 2, 'predicted_y': 0.11985995}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 2
# x: [0.465586, 1.052783]
# Score: 0.454892
# Using 2 dimensions.
# Points before downsampling: 160000
# Points after downsampling: 160000
# Final grid shape: (160000, 2)
# Filtered 4782 candidates near decision boundary (|margin| < 0.2)
# Excluded 155218 candidates from consideration
# Final grid shape: (4782, 2)
# Total number of points to evaluate: 9
# {'method': 'PI', 'xi': 0.01, 'kappa': None, 'x': array([0.46939502, 1.05009147]), 'score': 0.06198234896199505, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'PI', 'xi': 0.1, 'kappa': None, 'x': array([0.46939502, 1.05009147]), 'score': 0.009279970413964615, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'PI', 'xi': 0.3, 'kappa': None, 'x': array([0.46939502, 1.05009147]), 'score': 1.5405477528591152e-05, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'EI', 'xi': 0.01, 'kappa': None, 'x': array([0.46939502, 1.05009147]), 'score': 0.002960462721687214, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'EI', 'xi': 0.1, 'kappa': None, 'x': array([0.46939502, 1.05009147]), 'score': 0.0003441290916511332, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'EI', 'xi': 0.3, 'kappa': None, 'x': array([0.46939502, 1.05009147]), 'score': 3.705156345887953e-07, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'UCB', 'xi': None, 'kappa': 1.0, 'x': array([0.46939502, 1.05009147]), 'score': 0.22796748835352793, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'UCB', 'xi': None, 'kappa': 2.0, 'x': array([0.46939502, 1.05009147]), 'score': 0.33827370918805866, 'dim': 2, 'predicted_y': 0.11766127}
# {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.46939502, 1.05009147]), 'score': 0.44857993002258945, 'dim': 2, 'predicted_y': 0.11766127}
# 🔍 Best candidate (highest acquisition score):
# Method: UCB
# kappa: 3.0
# Dimensions: 2
# x: [0.469395, 1.050091]
# Score: 0.448580

# %%
# --- Loop over results and plot ---
for grid_size, (X_grid_filtered, mean, bounds, best, query_results, acq_maps) in results.items():
    print(f"\n=== Results for grid_size={grid_size} ===")

    # Extract candidates and labels
    candidates, labels = plotter.extract_candidates_and_labels(query_results, include_score=True)

    # Surrogate predictions plot
    plotter.plot_surrogate_generic(
        X_grid_filtered, mean,
        X_filtered=X_grid_filtered,
        bounds=bounds,
        candidates=candidates,
        candidate_labels=labels,
        title=f"Surrogate predictions (grid_size={grid_size})"
    )

    # Append candidates to BaseDataHandler and rebuild DataFrame
    cand_array, y_pred_array = dh.extract_candidate_arrays(query_results)
    dh.add_candidates(cand_array, y_pred_array)  # updates inputs/outputs/source_labels
    df_sorted = dh.build_dataframe()             # rebuild from updated arrays

    # Re-plot updated DataFrame
    plotter.plot_output_points(
        df_sorted,
        scale_factor=10.0,
        yield_scale_factor=10.0,
        source_marker='week-x',          # highlight all rows with source == 'week-x'
        source_color='red',
        source_marker_style='x'
    )
    # Print best candidate info
    print("Best candidate:", best)
# Out:
# === Results for grid_size=100 ===
# Best candidate: {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.46802608, 1.05224389]), 'score': 0.4530823477226964, 'dim': 2, 'predicted_y': 0.11855966}
#
# === Results for grid_size=200 ===
# Best candidate: {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.46558628, 1.05278335]), 'score': 0.45489194714993847, 'dim': 2, 'predicted_y': 0.11985995}
#
# === Results for grid_size=400 ===
# Best candidate: {'method': 'UCB', 'xi': None, 'kappa': 3.0, 'x': array([0.46939502, 1.05009147]), 'score': 0.44857993002258945, 'dim': 2, 'predicted_y': 0.11766127}
