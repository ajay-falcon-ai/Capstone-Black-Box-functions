# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)                  # Use unlimited width (auto-detect terminal size)
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)

# %%
# %run ../plot_functions.ipynb

# %%
# Track sources
source_labels = ['file'] * len(inputs)

# %%
#Append week-1 data.
#Function 1: input	[0.848485, 0.777778]
inputs = np.append(inputs, [[0.848485, 0.777778]], axis=0)
#Function 1:	-1.2487829338434956e-49
outputs = np.append(outputs, [-1.2487829338434956e-49], axis=0)

# %%
source_labels.append('week-1')

# %%
#Append week-2 data.
#Function 1:	[0.404040, 0.959596]
inputs = np.append(inputs, [[0.404040, 0.959596]], axis=0)
#Function 1:	-9.343447791332904e-112
outputs = np.append(outputs, [-9.343447791332904e-112], axis=0)

# %%
source_labels.append('week-2')

# %%
#Append week-3 data.
#Function 1:	[0.579291, 1.059596]
inputs = np.append(inputs, [[0.579291, 1.059596]], axis=0)
#Function 1:	4.5074380138539914e-133
outputs = np.append(outputs, [4.5074380138539914e-133], axis=0)
source_labels.append('week-3')

# %%
#Append week-4 data.
#Function 1:	[0.436769, 0.825163]
inputs = np.append(inputs, [[0.436769, 0.825163]], axis=0)
#Function 1:	-1.5199719684953676e-55
outputs = np.append(outputs, [-1.5199719684953676e-55], axis=0)
source_labels.append('week-4')

# %%
#Append week-5 data.
#Function 1:	[0.469395, 1.050091]
inputs = np.append(inputs, [[0.469395, 1.050091]], axis=0)
#Function 1:	-6.688485279296031e-142
outputs = np.append(outputs, [-6.688485279296031e-142], axis=0)
source_labels.append('week-5')

# %%
#Append week-6 data.
#Function 1:	[0.472352, 1.055087]
inputs = np.append(inputs, [[0.472352, 1.055087]], axis=0)
#Function 1:	-1.8022788966239472e-144
outputs = np.append(outputs, [-1.8022788966239472e-144], axis=0)
source_labels.append('week-6')

# %%
#Append week-7 data.
#Function 1:	[0.523861, 1.067166]
inputs = np.append(inputs, [[0.523861, 1.067166]], axis=0)
#Function 1:	-1.3151574669815363e-142
outputs = np.append(outputs, [-1.3151574669815363e-142], axis=0)
source_labels.append('week-7')

# %%
#Append week-8 data.
#Function 1:	[0.650000, 0.680000]
inputs = np.append(inputs, [[0.650000, 0.680000]], axis=0)
#Function 1:	-0.004236010437020722
outputs = np.append(outputs, [-0.004236010437020722], axis=0)
source_labels.append('week-8')

# %%
# Create DataFrame
df = pd.DataFrame(inputs, columns=['cont-src-1', 'cont-src-2'])
df['radiation-reading'] = outputs
df['source'] = source_labels

# Sort by transformed-side effect (larger is better)
df_sorted = df.sort_values(by='radiation-reading', ascending=False)

# Preview
print(df_sorted)
# Out:
#     cont-src-1  cont-src-2  radiation-reading  source
# 2     0.731024    0.733000       7.710875e-16    file
# 7     0.683418    0.861057       2.535001e-40    file
# 1     0.574329    0.879898       1.033078e-46    file
# 9     0.883890    0.582254       6.229856e-48    file
# 0     0.319404    0.762959       1.322677e-79    file
# 8     0.082507    0.403488       3.606771e-81    file
# 3     0.840353    0.264732      3.341771e-124    file
# 12    0.579291    1.059596      4.507438e-133  week-3
# 14    0.469395    1.050091     -6.688485e-142  week-5
# 11    0.404040    0.959596     -9.343448e-112  week-2
# 6     0.312691    0.078723      -2.089093e-91    file
# 13    0.436769    0.825163      -1.519972e-55  week-4
# 5     0.410437    0.147554      -2.159249e-54    file
# 10    0.848485    0.777778      -1.248783e-49  week-1
# 4     0.650114    0.681526      -3.606063e-03    file

# %%
plot_output_points(df_sorted, scale_factor=1.0, yield_scale_factor=500.0, nan_marker='o')
# Out:
# /var/folders/d6/s3jc1rb17y1411yjy8r6jlf80000gn/T/ipykernel_49311/923837372.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10', len(other_cols))
