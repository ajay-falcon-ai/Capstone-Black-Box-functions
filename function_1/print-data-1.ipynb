# %%
import numpy as np

# Load initial input data
inputs = np.load('initial_inputs.npy', allow_pickle=True)
#print(len(inputs))
print(inputs)
# Load initial output data
outputs = np.load('initial_outputs.npy', allow_pickle=True)
#print(len(outputs))
print(outputs)
# Out:
# [[0.31940389 0.76295937]
#  [0.57432921 0.8798981 ]
#  [0.73102363 0.73299988]
#  [0.84035342 0.26473161]
#  [0.65011406 0.68152635]
#  [0.41043714 0.1475543 ]
#  [0.31269116 0.07872278]
#  [0.68341817 0.86105746]
#  [0.08250725 0.40348751]
#  [0.88388983 0.58225397]]
# [ 1.32267704e-079  1.03307824e-046  7.71087511e-016  3.34177101e-124
#  -3.60606264e-003 -2.15924904e-054 -2.08909327e-091  2.53500115e-040
#   3.60677119e-081  6.22985647e-048]

# %%
def print_csv(arr):
    """
    Print a NumPy array as CSV:
    - One row per line
    - Comma-separated columns
    - If there's only one row, print each value on a new line
    """
    arr = np.asarray(arr)

    if arr.ndim == 0:
        # Scalar
        print(str(arr.item()))

    elif arr.ndim == 1:
        # 1D: treat as single row → print each value on its own line
        for val in arr:
            print(str(val))

    elif arr.ndim == 2:
        if arr.shape[0] == 1:
            # Single row → print each column value on its own line
            for val in arr[0]:
                print(str(val))
        else:
            # Multiple rows → print comma-separated
            for row in arr:
                print(','.join(map(str, row)))

    else:
        # 3D+ → flatten each leading slice to a row
        reshaped = arr.reshape(arr.shape[0], -1)
        for row in reshaped:
            print(','.join(map(str, row)))
print_csv(inputs)
print_csv(outputs)
# Out:
# 0.31940388883889725,0.7629593742689353
# 0.5743292145098291,0.879898104984359
# 0.7310236309563586,0.7329998764152272
# 0.8403534169072556,0.26473161399676703
# 0.6501140597987644,0.6815263520602101
# 0.41043713662518566,0.14755429902998185
# 0.31269115679477755,0.07872277794971883
# 0.6834181688515067,0.8610574643936101
# 0.08250725182080587,0.403487506426324
# 0.8838898288181171,0.5822539743824439
# 1.3226770395454077e-79
# 1.0330782375230975e-46
# 7.710875114502849e-16
# 3.341771007676023e-124
# -0.0036060626443634764
# -2.1592490357331095e-54
# -2.0890932702320842e-91
# 2.5350011535584046e-40
# 3.6067711901420254e-81
# 6.229856468168659e-48
